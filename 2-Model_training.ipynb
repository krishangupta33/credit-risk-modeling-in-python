# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the Data and Selecting the Features

# %% [markdown]
# ### Import Data

# %%
loan_data_inputs_train = pd.read_csv('processed_data/loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('processed_data/loan_data_targets_train.csv', index_col = 0)
loan_data_inputs_test = pd.read_csv('processed_data/loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('processed_data/loan_data_targets_test.csv', index_col = 0)

# %% [markdown]
# ### Explore Data

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 427211      427211  12796369   14818505      24000        24000
# 206088      206088   1439740    1691948      10000        10000
# 136020      136020   5214749    6556909      20425        20425
# 412305      412305  13827698   15890016      17200        17200
# 36159        36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 427211             1           0       0                              1
# 206088             0           0       0                              1
# 136020             0           0       0                              1
# 412305             0           0       0                              1
# 36159              0           1       0                              1
#
#         mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                           0                           0
# 206088                           0                           0
# 136020                           0                           0
# 412305                           0                           0
# 36159                            0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>86
# 427211                            0                          0
# 206088                            0                          0
# 136020                            0                          0
# 412305                            0                          0
# 36159                             0                          0
#
# [5 rows x 324 columns]

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 324)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 324)

# %%
loan_data_targets_test.shape
# Out:
# (93257, 1)

# %% [markdown]
# ### Selecting the Features

# %%
# Here we select a limited set of input variables in a new dataframe.
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
# 'mths_since_last_record:>=86',
]]

# %%
# Here we store the names of the reference category dummy variables in a list.
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
# From the dataframe with input variables, we drop the variables with variable names in the list with reference categories. 
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  dti:22.4-35  mths_since_last_delinq:Missing  \
# 427211              0  ...            0                               1
# 206088              0  ...            0                               0
# 136020              0  ...            0                               0
# 412305              0  ...            0                               0
# 36159               0  ...            1                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
# [5 rows x 103 columns]

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()
# We create an instance of an object from the 'LogisticRegression' class.

# %%
pd.options.display.max_rows = None
# Sets the pandas dataframe options to display all columns/ rows.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Displays the intercept contain in the estimated ("fitted") object from the 'LogisticRegression' class.
# Out:
# array([-1.03329742])

# %%
reg.coef_
# Displays the coefficients contained in the estimated ("fitted") object from the 'LogisticRegression' class.
# Out:
# array([[ 1.18947976,  0.91365406,  0.71396159,  0.52149539,  0.3399664 ,
#          0.14858617,  0.09173826,  0.10743324,  0.03769045,  0.0599238 ,
#          0.05977877,  0.06318501,  0.07967566,  0.13744521,  0.100451  ,
#          0.18640187,  0.2503985 ,  0.22459498,  0.26386237,  0.3216645 ,
#          0.52021056,  0.08600435, -0.01226999,  0.29518088,  0.19281734,
#          0.20469596,  0.25802846,  0.05489055,  0.07643314,  0.09668639,
#          0.12419187,  0.08934105,  0.05989393,  0.12146445,  1.09809647,
#          0.89494387,  0.79734343,  0.59538328,  0.43247213,  0.18758535,
#         -0.05051101,  0.83089441,  0.53911743,  0.29140811,  0.10482553,
#          0.05215983,  0.03602718,  0.07606817,  0.11690588,  0.12337493,
#          0.05580184,  0.02846652,  0.53607271,  0.39312186,  0.18129499,
#          0.01051457, -0.08638838, -0.11334585, -0.12899855, -0.12074853,
#         -0.11125748, -0.19057791,  0.12282575,  0.15409884, -0.02161867,
#          0.03335423,  0.26091597,  0.04126789,  0.00920861,  0.00678712,
#          0.01953939,  0.04116686,  0.06630958,  0.21953041, -0.05816705,
#          0.01078976,  0.10973464,  0.17906067,  0.2558593 ,  0.32873077,
#          0.40637765,  0.42454519,  0.50198377,  0.59278311,  0.51547619,
#          0.15792874,  0.27748294,  0.31499482,  0.25548791,  0.18005822,
#          0.08257119,  0.06866236,  0.03707625, -0.00305506,  0.13944614,
#          0.19357397,  0.21632143,  0.16865163,  0.10090422,  0.19185578,
#          0.12902666,  0.28506796, -0.04581984]])

# %%
feature_name = inputs_train.columns.values
# Stores the names of the columns of a dataframe in a variable.

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
# Creates a dataframe with a column titled 'Feature name' and row values contained in the 'feature_name' variable.
summary_table['Coefficients'] = np.transpose(reg.coef_)
# Creates a new column in the dataframe, called 'Coefficients',
# with row values the transposed coefficients from the 'LogisticRegression' object.
summary_table.index = summary_table.index + 1
# Increases the index of every row of the dataframe with 1.
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
# Assigns values of the row with index 0 of the dataframe.
summary_table = summary_table.sort_index()
# Sorts the dataframe by index.
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.033297
# 1                                grade:A      1.189480
# 2                                grade:B      0.913654
# 3                                grade:C      0.713962
# 4                                grade:D      0.521495
# 5                                grade:E      0.339966
# 6                                grade:F      0.148586
# 7                     home_ownership:OWN      0.091738
# 8                home_ownership:MORTGAGE      0.107433
# 9                       addr_state:NM_VA      0.037690
# 10                         addr_state:NY      0.059924
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.059779
# 12                         addr_state:CA      0.063185
# 13                addr_state:UT_KY_AZ_NJ      0.079676
# 14             addr_state:AR_MI_PA_OH_MN      0.137445
# 15             addr_state:RI_MA_DE_SD_IN      0.100451
# 16                   addr_state:GA_WA_OR      0.186402
# 17                      addr_state:WI_MT      0.250399
# 18                         addr_state:TX      0.224595
# 19                      addr_state:IL_CT      0.263862
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321665
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520211
# 22      verification_status:Not Verified      0.086004
# 23   verification_status:Source Verified     -0.012270
# 24                   purpose:credit_card      0.295181
# 25            purpose:debt_consolidation      0.192817
# 26            purpose:oth__med__vacation      0.204696
# 27   purpose:major_purch__car__home_impr      0.258028
# 28                 initial_list_status:w      0.054891
# 29                               term:36      0.076433
# 30                          emp_length:1      0.096686
# 31                        emp_length:2-4      0.124192
# 32                        emp_length:5-6      0.089341
# 33                        emp_length:7-9      0.059894
# 34                         emp_length:10      0.121464
# 35                mths_since_issue_d:<38      1.098096
# 36              mths_since_issue_d:38-39      0.894944
# 37              mths_since_issue_d:40-41      0.797343
# 38              mths_since_issue_d:42-48      0.595383
# 39              mths_since_issue_d:49-52      0.432472
# 40              mths_since_issue_d:53-64      0.187585
# 41              mths_since_issue_d:65-84     -0.050511
# 42                       int_rate:<9.548      0.830894
# 43                 int_rate:9.548-12.025      0.539117
# 44                 int_rate:12.025-15.74      0.291408
# 45                 int_rate:15.74-20.281      0.104826
# 46   mths_since_earliest_cr_line:141-164      0.052160
# 47   mths_since_earliest_cr_line:165-247      0.036027
# 48   mths_since_earliest_cr_line:248-270      0.076068
# 49   mths_since_earliest_cr_line:271-352      0.116906
# 50      mths_since_earliest_cr_line:>352      0.123375
# 51                         delinq_2yrs:0      0.055802
# 52                       delinq_2yrs:1-3      0.028467
# 53                      inq_last_6mths:0      0.536073
# 54                    inq_last_6mths:1-2      0.393122
# 55                    inq_last_6mths:3-6      0.181295
# 56                          open_acc:1-3      0.010515
# 57                         open_acc:4-12     -0.086388
# 58                        open_acc:13-17     -0.113346
# 59                        open_acc:18-22     -0.128999
# 60                        open_acc:23-25     -0.120749
# 61                        open_acc:26-30     -0.111257
# 62                         open_acc:>=31     -0.190578
# 63                           pub_rec:3-4      0.122826
# 64                           pub_rec:>=5      0.154099
# 65                       total_acc:28-51     -0.021619
# 66                        total_acc:>=52      0.033354
# 67                    acc_now_delinq:>=1      0.260916
# 68               total_rev_hi_lim:5K-10K      0.041268
# 69              total_rev_hi_lim:10K-20K      0.009209
# 70              total_rev_hi_lim:20K-30K      0.006787
# 71              total_rev_hi_lim:30K-40K      0.019539
# 72              total_rev_hi_lim:40K-55K      0.041167
# 73              total_rev_hi_lim:55K-95K      0.066310
# 74                 total_rev_hi_lim:>95K      0.219530
# 75                    annual_inc:20K-30K     -0.058167
# 76                    annual_inc:30K-40K      0.010790
# 77                    annual_inc:40K-50K      0.109735
# 78                    annual_inc:50K-60K      0.179061
# 79                    annual_inc:60K-70K      0.255859
# 80                    annual_inc:70K-80K      0.328731
# 81                    annual_inc:80K-90K      0.406378
# 82                   annual_inc:90K-100K      0.424545
# 83                  annual_inc:100K-120K      0.501984
# 84                  annual_inc:120K-140K      0.592783
# 85                      annual_inc:>140K      0.515476
# 86                             dti:<=1.4      0.157929
# 87                           dti:1.4-3.5      0.277483
# 88                           dti:3.5-7.7      0.314995
# 89                          dti:7.7-10.5      0.255488
# 90                         dti:10.5-16.1      0.180058
# 91                         dti:16.1-20.3      0.082571
# 92                         dti:20.3-21.7      0.068662
# 93                         dti:21.7-22.4      0.037076
# 94                           dti:22.4-35     -0.003055
# 95        mths_since_last_delinq:Missing      0.139446
# 96           mths_since_last_delinq:4-30      0.193574
# 97          mths_since_last_delinq:31-56      0.216321
# 98           mths_since_last_delinq:>=57      0.168652
# 99        mths_since_last_record:Missing      0.100904
# 100          mths_since_last_record:3-20      0.191856
# 101         mths_since_last_record:21-31      0.129027
# 102         mths_since_last_record:32-80      0.285068
# 103         mths_since_last_record:81-86     -0.045820

# %% [markdown]
# ## Build a Logistic Regression Model with P-Values

# %%
# P values for sklearn logistic regression.

# Class to display p-values for logistic regression in sklearn.

from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):#,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)#,**args)

    def fit(self,X,y):
        self.model.fit(X,y)
        
        #### Get p-values for the fitted model ####
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) ## Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) ## Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates # z-score for eaach model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] ### two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()
# We create an instance of an object from the newly created 'LogisticRegression_with_p_values()' class.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.033297
# 1                                grade:A      1.189480
# 2                                grade:B      0.913654
# 3                                grade:C      0.713962
# 4                                grade:D      0.521495
# 5                                grade:E      0.339966
# 6                                grade:F      0.148586
# 7                     home_ownership:OWN      0.091738
# 8                home_ownership:MORTGAGE      0.107433
# 9                       addr_state:NM_VA      0.037690
# 10                         addr_state:NY      0.059924
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.059779
# 12                         addr_state:CA      0.063185
# 13                addr_state:UT_KY_AZ_NJ      0.079676
# 14             addr_state:AR_MI_PA_OH_MN      0.137445
# 15             addr_state:RI_MA_DE_SD_IN      0.100451
# 16                   addr_state:GA_WA_OR      0.186402
# 17                      addr_state:WI_MT      0.250399
# 18                         addr_state:TX      0.224595
# 19                      addr_state:IL_CT      0.263862
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321665
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520211
# 22      verification_status:Not Verified      0.086004
# 23   verification_status:Source Verified     -0.012270
# 24                   purpose:credit_card      0.295181
# 25            purpose:debt_consolidation      0.192817
# 26            purpose:oth__med__vacation      0.204696
# 27   purpose:major_purch__car__home_impr      0.258028
# 28                 initial_list_status:w      0.054891
# 29                               term:36      0.076433
# 30                          emp_length:1      0.096686
# 31                        emp_length:2-4      0.124192
# 32                        emp_length:5-6      0.089341
# 33                        emp_length:7-9      0.059894
# 34                         emp_length:10      0.121464
# 35                mths_since_issue_d:<38      1.098096
# 36              mths_since_issue_d:38-39      0.894944
# 37              mths_since_issue_d:40-41      0.797343
# 38              mths_since_issue_d:42-48      0.595383
# 39              mths_since_issue_d:49-52      0.432472
# 40              mths_since_issue_d:53-64      0.187585
# 41              mths_since_issue_d:65-84     -0.050511
# 42                       int_rate:<9.548      0.830894
# 43                 int_rate:9.548-12.025      0.539117
# 44                 int_rate:12.025-15.74      0.291408
# 45                 int_rate:15.74-20.281      0.104826
# 46   mths_since_earliest_cr_line:141-164      0.052160
# 47   mths_since_earliest_cr_line:165-247      0.036027
# 48   mths_since_earliest_cr_line:248-270      0.076068
# 49   mths_since_earliest_cr_line:271-352      0.116906
# 50      mths_since_earliest_cr_line:>352      0.123375
# 51                         delinq_2yrs:0      0.055802
# 52                       delinq_2yrs:1-3      0.028467
# 53                      inq_last_6mths:0      0.536073
# 54                    inq_last_6mths:1-2      0.393122
# 55                    inq_last_6mths:3-6      0.181295
# 56                          open_acc:1-3      0.010515
# 57                         open_acc:4-12     -0.086388
# 58                        open_acc:13-17     -0.113346
# 59                        open_acc:18-22     -0.128999
# 60                        open_acc:23-25     -0.120749
# 61                        open_acc:26-30     -0.111257
# 62                         open_acc:>=31     -0.190578
# 63                           pub_rec:3-4      0.122826
# 64                           pub_rec:>=5      0.154099
# 65                       total_acc:28-51     -0.021619
# 66                        total_acc:>=52      0.033354
# 67                    acc_now_delinq:>=1      0.260916
# 68               total_rev_hi_lim:5K-10K      0.041268
# 69              total_rev_hi_lim:10K-20K      0.009209
# 70              total_rev_hi_lim:20K-30K      0.006787
# 71              total_rev_hi_lim:30K-40K      0.019539
# 72              total_rev_hi_lim:40K-55K      0.041167
# 73              total_rev_hi_lim:55K-95K      0.066310
# 74                 total_rev_hi_lim:>95K      0.219530
# 75                    annual_inc:20K-30K     -0.058167
# 76                    annual_inc:30K-40K      0.010790
# 77                    annual_inc:40K-50K      0.109735
# 78                    annual_inc:50K-60K      0.179061
# 79                    annual_inc:60K-70K      0.255859
# 80                    annual_inc:70K-80K      0.328731
# 81                    annual_inc:80K-90K      0.406378
# 82                   annual_inc:90K-100K      0.424545
# 83                  annual_inc:100K-120K      0.501984
# 84                  annual_inc:120K-140K      0.592783
# 85                      annual_inc:>140K      0.515476
# 86                             dti:<=1.4      0.157929
# 87                           dti:1.4-3.5      0.277483
# 88                           dti:3.5-7.7      0.314995
# 89                          dti:7.7-10.5      0.255488
# 90                         dti:10.5-16.1      0.180058
# 91                         dti:16.1-20.3      0.082571
# 92                         dti:20.3-21.7      0.068662
# 93                         dti:21.7-22.4      0.037076
# 94                           dti:22.4-35     -0.003055
# 95        mths_since_last_delinq:Missing      0.139446
# 96           mths_since_last_delinq:4-30      0.193574
# 97          mths_since_last_delinq:31-56      0.216321
# 98           mths_since_last_delinq:>=57      0.168652
# 99        mths_since_last_record:Missing      0.100904
# 100          mths_since_last_record:3-20      0.191856
# 101         mths_since_last_record:21-31      0.129027
# 102         mths_since_last_record:32-80      0.285068
# 103         mths_since_last_record:81-86     -0.045820

# %%
# This is a list.
p_values = reg.p_values
# We take the result of the newly added method 'p_values' and store it in a variable 'p_values'.

# %%
# Add the intercept for completeness.
p_values = np.append(np.nan, np.array(p_values))
# We add the value 'NaN' in the beginning of the variable with p-values.

# %%
summary_table['p_values'] = p_values
# In the 'summary_table' dataframe, we add a new column, called 'p_values', containing the values from the 'p_values' variable.

# %%
summary_table
# Out:
#                             Feature name  Coefficients       p_values
# 0                              Intercept     -1.033297            NaN
# 1                                grade:A      1.189480   8.857161e-40
# 2                                grade:B      0.913654   8.361308e-51
# 3                                grade:C      0.713962   1.491356e-36
# 4                                grade:D      0.521495   2.755896e-22
# 5                                grade:E      0.339966   1.485920e-12
# 6                                grade:F      0.148586   3.020863e-03
# 7                     home_ownership:OWN      0.091738   5.441560e-06
# 8                home_ownership:MORTGAGE      0.107433   2.672661e-17
# 9                       addr_state:NM_VA      0.037690   2.398188e-01
# 10                         addr_state:NY      0.059924   1.361416e-02
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.059779   9.993154e-03
# 12                         addr_state:CA      0.063185   2.931119e-03
# 13                addr_state:UT_KY_AZ_NJ      0.079676   1.409347e-03
# 14             addr_state:AR_MI_PA_OH_MN      0.137445   1.139594e-09
# 15             addr_state:RI_MA_DE_SD_IN      0.100451   7.716615e-04
# 16                   addr_state:GA_WA_OR      0.186402   3.012410e-12
# 17                      addr_state:WI_MT      0.250399   1.549541e-07
# 18                         addr_state:TX      0.224595   6.006249e-18
# 19                      addr_state:IL_CT      0.263862   1.895862e-19
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321665   2.018906e-25
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520211   1.329490e-22
# 22      verification_status:Not Verified      0.086004   4.665683e-09
# 23   verification_status:Source Verified     -0.012270   3.624511e-01
# 24                   purpose:credit_card      0.295181   3.718006e-25
# 25            purpose:debt_consolidation      0.192817   1.904454e-13
# 26            purpose:oth__med__vacation      0.204696   5.901840e-11
# 27   purpose:major_purch__car__home_impr      0.258028   2.090216e-16
# 28                 initial_list_status:w      0.054891   2.626003e-05
# 29                               term:36      0.076433   7.045319e-08
# 30                          emp_length:1      0.096686   1.950157e-04
# 31                        emp_length:2-4      0.124192   4.915131e-11
# 32                        emp_length:5-6      0.089341   3.026251e-05
# 33                        emp_length:7-9      0.059894   4.002720e-03
# 34                         emp_length:10      0.121464   4.571194e-11
# 35                mths_since_issue_d:<38      1.098096  3.405677e-183
# 36              mths_since_issue_d:38-39      0.894944  1.876764e-152
# 37              mths_since_issue_d:40-41      0.797343  1.803238e-127
# 38              mths_since_issue_d:42-48      0.595383   4.900458e-91
# 39              mths_since_issue_d:49-52      0.432472   5.710492e-43
# 40              mths_since_issue_d:53-64      0.187585   2.372129e-10
# 41              mths_since_issue_d:65-84     -0.050511   7.933561e-02
# 42                       int_rate:<9.548      0.830894   3.709102e-28
# 43                 int_rate:9.548-12.025      0.539117   2.442906e-33
# 44                 int_rate:12.025-15.74      0.291408   2.774396e-15
# 45                 int_rate:15.74-20.281      0.104826   3.161116e-04
# 46   mths_since_earliest_cr_line:141-164      0.052160   3.678207e-02
# 47   mths_since_earliest_cr_line:165-247      0.036027   7.709927e-02
# 48   mths_since_earliest_cr_line:248-270      0.076068   4.251771e-03
# 49   mths_since_earliest_cr_line:271-352      0.116906   1.016158e-06
# 50      mths_since_earliest_cr_line:>352      0.123375   5.104995e-06
# 51                         delinq_2yrs:0      0.055802   3.281596e-01
# 52                       delinq_2yrs:1-3      0.028467   5.966708e-01
# 53                      inq_last_6mths:0      0.536073   4.341391e-06
# 54                    inq_last_6mths:1-2      0.393122   7.417530e-04
# 55                    inq_last_6mths:3-6      0.181295   1.213729e-01
# 56                          open_acc:1-3      0.010515   9.481217e-01
# 57                         open_acc:4-12     -0.086388   5.831272e-01
# 58                        open_acc:13-17     -0.113346   4.723804e-01
# 59                        open_acc:18-22     -0.128999   4.164678e-01
# 60                        open_acc:23-25     -0.120749   4.603844e-01
# 61                        open_acc:26-30     -0.111257   5.097806e-01
# 62                         open_acc:>=31     -0.190578   2.984750e-01
# 63                           pub_rec:3-4      0.122826   1.951248e-01
# 64                           pub_rec:>=5      0.154099   4.199351e-01
# 65                       total_acc:28-51     -0.021619   1.279775e-01
# 66                        total_acc:>=52      0.033354   4.024451e-01
# 67                    acc_now_delinq:>=1      0.260916   1.319915e-02
# 68               total_rev_hi_lim:5K-10K      0.041268   9.369789e-02
# 69              total_rev_hi_lim:10K-20K      0.009209   6.996410e-01
# 70              total_rev_hi_lim:20K-30K      0.006787   7.958381e-01
# 71              total_rev_hi_lim:30K-40K      0.019539   5.069047e-01
# 72              total_rev_hi_lim:40K-55K      0.041167   2.004131e-01
# 73              total_rev_hi_lim:55K-95K      0.066310   6.571673e-02
# 74                 total_rev_hi_lim:>95K      0.219530   1.080995e-04
# 75                    annual_inc:20K-30K     -0.058167   1.748490e-01
# 76                    annual_inc:30K-40K      0.010790   7.942435e-01
# 77                    annual_inc:40K-50K      0.109735   8.058048e-03
# 78                    annual_inc:50K-60K      0.179061   2.016709e-05
# 79                    annual_inc:60K-70K      0.255859   2.724112e-09
# 80                    annual_inc:70K-80K      0.328731   7.254630e-14
# 81                    annual_inc:80K-90K      0.406378   6.596593e-19
# 82                   annual_inc:90K-100K      0.424545   3.153430e-19
# 83                  annual_inc:100K-120K      0.501984   1.532728e-26
# 84                  annual_inc:120K-140K      0.592783   1.053160e-28
# 85                      annual_inc:>140K      0.515476   2.125103e-25
# 86                             dti:<=1.4      0.157929   7.639910e-02
# 87                           dti:1.4-3.5      0.277483   2.404791e-04
# 88                           dti:3.5-7.7      0.314995   1.939806e-06
# 89                          dti:7.7-10.5      0.255488   9.861530e-05
# 90                         dti:10.5-16.1      0.180058   4.673936e-03
# 91                         dti:16.1-20.3      0.082571   1.943472e-01
# 92                         dti:20.3-21.7      0.068662   2.984230e-01
# 93                         dti:21.7-22.4      0.037076   5.952933e-01
# 94                           dti:22.4-35     -0.003055   9.612516e-01
# 95        mths_since_last_delinq:Missing      0.139446   8.921251e-03
# 96           mths_since_last_delinq:4-30      0.193574   1.045159e-04
# 97          mths_since_last_delinq:31-56      0.216321   7.721088e-05
# 98           mths_since_last_delinq:>=57      0.168652   2.570520e-03
# 99        mths_since_last_record:Missing      0.100904   5.218678e-06
# 100          mths_since_last_record:3-20      0.191856   4.476379e-02
# 101         mths_since_last_record:21-31      0.129027   1.129817e-01
# 102         mths_since_last_record:32-80      0.285068   7.629957e-18
# 103         mths_since_last_record:81-86     -0.045820   4.837721e-01

# %%
# We are going to remove some features, the coefficients for all or almost all of the dummy variables for which,
# are not statistically significant.

# We do that by specifying another list of dummy variables as reference categories, and a list of variables to remove.
# Then, we are going to drop the two datasets from the original list of dummy variables.

# Variables
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
# 'mths_since_last_record:>=86',
]]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  dti:22.4-35  mths_since_last_delinq:Missing  \
# 427211              0  ...            0                               1
# 206088              0  ...            0                               0
# 136020              0  ...            0                               0
# 412305              0  ...            0                               0
# 36159               0  ...            1                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
# [5 rows x 83 columns]

# %%
# Here we run a new model.
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.286591
# 1                               grade:A      1.155571
# 2                               grade:B      0.912941
# 3                               grade:C      0.716389
# 4                               grade:D      0.525339
# 5                               grade:E      0.342274
# 6                               grade:F      0.152211
# 7                    home_ownership:OWN      0.093715
# 8               home_ownership:MORTGAGE      0.106218
# 9                      addr_state:NM_VA      0.036094
# 10                        addr_state:NY      0.057791
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12                        addr_state:CA      0.063947
# 13               addr_state:UT_KY_AZ_NJ      0.078982
# 14            addr_state:AR_MI_PA_OH_MN      0.136947
# 15            addr_state:RI_MA_DE_SD_IN      0.101652
# 16                  addr_state:GA_WA_OR      0.185745
# 17                     addr_state:WI_MT      0.240440
# 18                        addr_state:TX      0.222863
# 19                     addr_state:IL_CT      0.262767
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22     verification_status:Not Verified      0.084431
# 23  verification_status:Source Verified     -0.010562
# 24                  purpose:credit_card      0.300414
# 25           purpose:debt_consolidation      0.197167
# 26           purpose:oth__med__vacation      0.213260
# 27  purpose:major_purch__car__home_impr      0.265543
# 28                initial_list_status:w      0.054820
# 29                              term:36      0.078659
# 30                         emp_length:1      0.099202
# 31                       emp_length:2-4      0.126174
# 32                       emp_length:5-6      0.091429
# 33                       emp_length:7-9      0.061589
# 34                        emp_length:10      0.125337
# 35               mths_since_issue_d:<38      1.091989
# 36             mths_since_issue_d:38-39      0.890632
# 37             mths_since_issue_d:40-41      0.788919
# 38             mths_since_issue_d:42-48      0.587156
# 39             mths_since_issue_d:49-52      0.425050
# 40             mths_since_issue_d:53-64      0.178656
# 41             mths_since_issue_d:65-84     -0.060627
# 42                      int_rate:<9.548      0.867413
# 43                int_rate:9.548-12.025      0.540433
# 44                int_rate:12.025-15.74      0.291225
# 45                int_rate:15.74-20.281      0.103115
# 46  mths_since_earliest_cr_line:141-164      0.056445
# 47  mths_since_earliest_cr_line:165-247      0.038179
# 48  mths_since_earliest_cr_line:248-270      0.080629
# 49  mths_since_earliest_cr_line:271-352      0.122844
# 50     mths_since_earliest_cr_line:>352      0.131433
# 51                     inq_last_6mths:0      0.694467
# 52                   inq_last_6mths:1-2      0.547350
# 53                   inq_last_6mths:3-6      0.336636
# 54                   acc_now_delinq:>=1      0.235441
# 55                   annual_inc:20K-30K     -0.068937
# 56                   annual_inc:30K-40K     -0.005534
# 57                   annual_inc:40K-50K      0.089310
# 58                   annual_inc:50K-60K      0.156335
# 59                   annual_inc:60K-70K      0.231736
# 60                   annual_inc:70K-80K      0.306244
# 61                   annual_inc:80K-90K      0.380310
# 62                  annual_inc:90K-100K      0.400761
# 63                 annual_inc:100K-120K      0.479389
# 64                 annual_inc:120K-140K      0.577045
# 65                     annual_inc:>140K      0.505300
# 66                            dti:<=1.4      0.252542
# 67                          dti:1.4-3.5      0.371502
# 68                          dti:3.5-7.7      0.389219
# 69                         dti:7.7-10.5      0.324630
# 70                        dti:10.5-16.1      0.245254
# 71                        dti:16.1-20.3      0.143909
# 72                        dti:20.3-21.7      0.132743
# 73                        dti:21.7-22.4      0.097494
# 74                          dti:22.4-35      0.054607
# 75       mths_since_last_delinq:Missing      0.167530
# 76          mths_since_last_delinq:4-30      0.192270
# 77         mths_since_last_delinq:31-56      0.239036
# 78          mths_since_last_delinq:>=57      0.191775
# 79       mths_since_last_record:Missing      0.102728
# 80          mths_since_last_record:3-20      0.212815
# 81         mths_since_last_record:21-31      0.135716
# 82         mths_since_last_record:32-80      0.286677
# 83         mths_since_last_record:81-86     -0.049871

# %%
# We add the 'p_values' here, just as we did before.
p_values = reg2.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Here we get the results for our final PD model.
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.286591            NaN
# 1                               grade:A      1.155571   2.054571e-37
# 2                               grade:B      0.912941   2.731773e-51
# 3                               grade:C      0.716389   2.225365e-37
# 4                               grade:D      0.525339   4.191192e-23
# 5                               grade:E      0.342274   3.044944e-13
# 6                               grade:F      0.152211   1.812154e-03
# 7                    home_ownership:OWN      0.093715   3.282189e-06
# 8               home_ownership:MORTGAGE      0.106218   4.428816e-17
# 9                      addr_state:NM_VA      0.036094   2.594831e-01
# 10                        addr_state:NY      0.057791   1.698910e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059826   9.726920e-03
# 12                        addr_state:CA      0.063947   2.537804e-03
# 13               addr_state:UT_KY_AZ_NJ      0.078982   1.514118e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.136947   1.151591e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.101652   6.562288e-04
# 16                  addr_state:GA_WA_OR      0.185745   3.201430e-12
# 17                     addr_state:WI_MT      0.240440   4.240665e-07
# 18                        addr_state:TX      0.222863   9.250644e-18
# 19                     addr_state:IL_CT      0.262767   2.218063e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930   2.185174e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524189   6.882691e-23
# 22     verification_status:Not Verified      0.084431   7.097765e-09
# 23  verification_status:Source Verified     -0.010562   4.316255e-01
# 24                  purpose:credit_card      0.300414   2.051002e-26
# 25           purpose:debt_consolidation      0.197167   3.172050e-14
# 26           purpose:oth__med__vacation      0.213260   6.773720e-12
# 27  purpose:major_purch__car__home_impr      0.265543   1.653427e-17
# 28                initial_list_status:w      0.054820   2.676211e-05
# 29                              term:36      0.078659   1.812804e-08
# 30                         emp_length:1      0.099202   1.301621e-04
# 31                       emp_length:2-4      0.126174   2.247723e-11
# 32                       emp_length:5-6      0.091429   1.923635e-05
# 33                       emp_length:7-9      0.061589   3.054330e-03
# 34                        emp_length:10      0.125337   1.034983e-11
# 35               mths_since_issue_d:<38      1.091989  7.307195e-189
# 36             mths_since_issue_d:38-39      0.890632  1.158310e-158
# 37             mths_since_issue_d:40-41      0.788919  1.874188e-131
# 38             mths_since_issue_d:42-48      0.587156   4.827482e-94
# 39             mths_since_issue_d:49-52      0.425050   8.032616e-44
# 40             mths_since_issue_d:53-64      0.178656   5.217626e-10
# 41             mths_since_issue_d:65-84     -0.060627   3.499544e-02
# 42                      int_rate:<9.548      0.867413   3.709293e-30
# 43                int_rate:9.548-12.025      0.540433   7.714578e-34
# 44                int_rate:12.025-15.74      0.291225   1.984920e-15
# 45                int_rate:15.74-20.281      0.103115   3.683881e-04
# 46  mths_since_earliest_cr_line:141-164      0.056445   2.316610e-02
# 47  mths_since_earliest_cr_line:165-247      0.038179   5.685032e-02
# 48  mths_since_earliest_cr_line:248-270      0.080629   2.091505e-03
# 49  mths_since_earliest_cr_line:271-352      0.122844   1.497001e-07
# 50     mths_since_earliest_cr_line:>352      0.131433   6.940027e-07
# 51                     inq_last_6mths:0      0.694467   8.171735e-18
# 52                   inq_last_6mths:1-2      0.547350   1.182933e-11
# 53                   inq_last_6mths:3-6      0.336636   3.563451e-05
# 54                   acc_now_delinq:>=1      0.235441   2.326845e-02
# 55                   annual_inc:20K-30K     -0.068937   9.947818e-02
# 56                   annual_inc:30K-40K     -0.005534   8.904890e-01
# 57                   annual_inc:40K-50K      0.089310   2.606733e-02
# 58                   annual_inc:50K-60K      0.156335   1.207766e-04
# 59                   annual_inc:60K-70K      0.231736   2.552314e-08
# 60                   annual_inc:70K-80K      0.306244   5.402130e-13
# 61                   annual_inc:80K-90K      0.380310   7.968175e-18
# 62                  annual_inc:90K-100K      0.400761   2.166493e-18
# 63                 annual_inc:100K-120K      0.479389   4.984335e-26
# 64                 annual_inc:120K-140K      0.577045   7.341082e-29
# 65                     annual_inc:>140K      0.505300   1.348163e-26
# 66                            dti:<=1.4      0.252542   2.330160e-03
# 67                          dti:1.4-3.5      0.371502   8.811998e-08
# 68                          dti:3.5-7.7      0.389219   6.677722e-11
# 69                         dti:7.7-10.5      0.324630   4.306794e-08
# 70                        dti:10.5-16.1      0.245254   1.825593e-05
# 71                        dti:16.1-20.3      0.143909   1.207483e-02
# 72                        dti:20.3-21.7      0.132743   2.711004e-02
# 73                        dti:21.7-22.4      0.097494   1.288914e-01
# 74                          dti:22.4-35      0.054607   3.354135e-01
# 75       mths_since_last_delinq:Missing      0.167530   3.993944e-04
# 76          mths_since_last_delinq:4-30      0.192270   6.766861e-05
# 77         mths_since_last_delinq:31-56      0.239036   1.034442e-06
# 78          mths_since_last_delinq:>=57      0.191775   1.379534e-04
# 79       mths_since_last_record:Missing      0.102728   2.755594e-06
# 80          mths_since_last_record:3-20      0.212815   2.358424e-02
# 81         mths_since_last_record:21-31      0.135716   9.164776e-02
# 82         mths_since_last_record:32-80      0.286677   1.251221e-18
# 83         mths_since_last_record:81-86     -0.049871   4.455653e-01

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))
# Here we export our model to a 'SAV' file with file name 'pd_model.sav'.

# %% [markdown]
# # PD Model Validation (Test)

# %% [markdown]
# ### Out-of-sample validation (test)

# %%
# Here, from the dataframe with inputs for testing, we keep the same variables that we used in our final PD model.
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
# 'mths_since_last_record:>=86',
]]

# %%
# And here, in the list below, we keep the variable names for the reference categories,
# only for the variables we used in our final PD model.
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514        0        0        1        0        0        0
# 288564        0        0        0        0        1        0
# 213591        0        0        1        0        0        0
# 263083        0        0        1        0        0        0
# 165001        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  ...  dti:22.4-35  mths_since_last_delinq:Missing  \
# 362514              0  ...            0                               1
# 288564              0  ...            1                               0
# 213591              0  ...            0                               0
# 263083              0  ...            0                               1
# 165001              0  ...            0                               0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
# [5 rows x 83 columns]

# %%
y_hat_test = reg2.model.predict(inputs_test)
# Calculates the predicted values for the dependent variable (targets)
# based on the values of the independent variables (inputs) supplied as an argument.

# %%
y_hat_test
# This is an array of predicted discrete classess (in this case, 0s and 1s).
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)
# Calculates the predicted probability values for the dependent variable (targets)
# based on the values of the independent variables (inputs) supplied as an argument.

# %%
y_hat_test_proba
# This is an array of arrays of predicted class probabilities for all classes.
# In this case, the first value of every sub-array is the probability for the observation to belong to the first class, i.e. 0,
# and the second value is the probability for the observation to belong to the first class, i.e. 1.
# Out:
# array([[0.07551392, 0.92448608],
#        [0.15695345, 0.84304655],
#        [0.11449883, 0.88550117],
#        ...,
#        [0.02674726, 0.97325274],
#        [0.04018613, 0.95981387],
#        [0.04776354, 0.95223646]])

# %%
y_hat_test_proba[:][:,1]
# Here we take all the arrays in the array, and from each array, we take all rows, and only the element with index 1,
# that is, the second element.
# In other words, we take only the probabilities for being 1.
# Out:
# array([0.92448608, 0.84304655, 0.88550117, ..., 0.97325274, 0.95981387,
#        0.95223646])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]
# We store these probabilities in a variable.

# %%
y_hat_test_proba
# This variable contains an array of probabilities of being 1.
# Out:
# array([0.92448608, 0.84304655, 0.88550117, ..., 0.97325274, 0.95981387,
#        0.95223646])

# %%
loan_data_targets_test_temp = loan_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)
# We reset the index of a dataframe.

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)
# Concatenates two dataframes.

# %%
df_actual_predicted_probs.shape
# Out:
# (93257, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_test.index
# Makes the index of one dataframe equal to the index of another dataframe.

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 362514                       1          0.924486
# 288564                       1          0.843047
# 213591                       1          0.885501
# 263083                       1          0.940707
# 165001                       1          0.968689

# %% [markdown]
# ### Accuracy and Area under the Curve

# %%
tr = 0.9
# We create a new column with an indicator,
# where every observation that has predicted probability greater than the threshold has a value of 1,
# and every observation that has predicted probability lower than the threshold has a value of 0.
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Creates a cross-table where the actual values are displayed by rows and the predicted values by columns.
# This table is known as a Confusion Matrix.
# Out:
# Predicted      0      1
# Actual
# 0           7379   2811
# 1          35830  47237

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Here we divide each value of the table by the total number of observations,
# thus getting percentages, or, rates.
# Out:
# Predicted         0         1
# Actual
# 0          0.079125  0.030143
# 1          0.384207  0.506525

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Here we calculate Accuracy of the model, which is the sum of the diagonal rates.
# Out:
# 0.5856504069399616

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Returns the Receiver Operating Characteristic (ROC) Curve from a set of actual values and their predicted probabilities.
# As a result, we get three arrays: the false positive rates, the true positive rates, and the thresholds.
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99990186, 0.99990186,
#         1.        ]),
#  array([0.00000000e+00, 1.20384750e-05, 1.20384750e-04, ...,
#         9.99975923e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([1.99271448, 0.99271448, 0.99072892, ..., 0.43531043, 0.39807591,
#         0.38087713]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Here we store each of the three arrays in a separate variable.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
# We plot the false positive rate along the x-axis and the true positive rate along the y-axis,
# thus plotting the ROC curve.
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
# We plot a seconary diagonal line, with dashed line style and black color.
plt.xlabel('False positive rate')
# We name the x-axis "False positive rate".
plt.ylabel('True positive rate')
# We name the x-axis "True positive rate".
plt.title('ROC curve')
# We name the graph "ROC curve".
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Calculates the Area Under the Receiver Operating Characteristic Curve (AUROC)
# from a set of actual values and their predicted probabilities.
AUROC
# Out:
# 0.702082145213236

# %% [markdown]
# ### Gini and Kolmogorov-Smirnov

# %%
df_actual_predicted_probs = df_actual_predicted_probs.sort_values('y_hat_test_proba')
# Sorts a dataframe by the values of a specific column.

# %%
df_actual_predicted_probs.head()
# Out:
#        loan_data_targets_test  y_hat_test_proba  y_hat_test
# 39810                       0          0.380877           0
# 42341                       1          0.398076           0
# 42344                       1          0.431713           0
# 40518                       0          0.435310           0
# 40173                       0          0.455460           0

# %%
df_actual_predicted_probs.tail()
# Out:
#         loan_data_targets_test  y_hat_test_proba  y_hat_test
# 262480                       1          0.991275           1
# 231463                       1          0.991295           1
# 239228                       1          0.991679           1
# 261086                       1          0.992112           1
# 242624                       1          0.992714           1

# %%
df_actual_predicted_probs = df_actual_predicted_probs.reset_index()
# We reset the index of a dataframe and overwrite it.

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test
# 0  39810                       0          0.380877           0
# 1  42341                       1          0.398076           0
# 2  42344                       1          0.431713           0
# 3  40518                       0          0.435310           0
# 4  40173                       0          0.455460           0

# %%
df_actual_predicted_probs['Cumulative N Population'] = df_actual_predicted_probs.index + 1
# We calculate the cumulative number of all observations.
# We use the new index for that. Since indexing in ython starts from 0, we add 1 to each index.
df_actual_predicted_probs['Cumulative N Good'] = df_actual_predicted_probs['loan_data_targets_test'].cumsum()
# We calculate cumulative number of 'good', which is the cumulative sum of the column with actual observations.
df_actual_predicted_probs['Cumulative N Bad'] = df_actual_predicted_probs['Cumulative N Population'] - df_actual_predicted_probs['loan_data_targets_test'].cumsum()
# We calculate cumulative number of 'bad', which is
# the difference between the cumulative number of all observations and cumulative number of 'good' for each row.

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  39810                       0          0.380877           0
# 1  42341                       1          0.398076           0
# 2  42344                       1          0.431713           0
# 3  40518                       0          0.435310           0
# 4  40173                       0          0.455460           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad
# 0                        1                  0                 1
# 1                        2                  1                 1
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3

# %%
df_actual_predicted_probs['Cumulative Perc Population'] = df_actual_predicted_probs['Cumulative N Population'] / (df_actual_predicted_probs.shape[0])
# We calculate the cumulative percentage of all observations.
df_actual_predicted_probs['Cumulative Perc Good'] = df_actual_predicted_probs['Cumulative N Good'] / df_actual_predicted_probs['loan_data_targets_test'].sum()
# We calculate cumulative percentage of 'good'.
df_actual_predicted_probs['Cumulative Perc Bad'] = df_actual_predicted_probs['Cumulative N Bad'] / (df_actual_predicted_probs.shape[0] - df_actual_predicted_probs['loan_data_targets_test'].sum())
# We calculate the cumulative percentage of 'bad'.

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  39810                       0          0.380877           0
# 1  42341                       1          0.398076           0
# 2  42344                       1          0.431713           0
# 3  40518                       0          0.435310           0
# 4  40173                       0          0.455460           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 0                        1                  0                 1
# 1                        2                  1                 1
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3
#
#    Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 0                    0.000011              0.000000             0.000098
# 1                    0.000021              0.000012             0.000098
# 2                    0.000032              0.000024             0.000098
# 3                    0.000043              0.000024             0.000196
# 4                    0.000054              0.000024             0.000294

# %%
df_actual_predicted_probs.tail()
# Out:
#         index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 93252  262480                       1          0.991275           1
# 93253  231463                       1          0.991295           1
# 93254  239228                       1          0.991679           1
# 93255  261086                       1          0.992112           1
# 93256  242624                       1          0.992714           1
#
#        Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 93252                    93253              83063             10190
# 93253                    93254              83064             10190
# 93254                    93255              83065             10190
# 93255                    93256              83066             10190
# 93256                    93257              83067             10190
#
#        Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 93252                    0.999957              0.999952                  1.0
# 93253                    0.999968              0.999964                  1.0
# 93254                    0.999979              0.999976                  1.0
# 93255                    0.999989              0.999988                  1.0
# 93256                    1.000000              1.000000                  1.0

# %%
# Plot Gini
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Bad'])
# We plot the cumulative percentage of all along the x-axis and the cumulative percentage 'good' along the y-axis,
# thus plotting the Gini curve.
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Population'], linestyle = '--', color = 'k')
# We plot a seconary diagonal line, with dashed line style and black color.
plt.xlabel('Cumulative % Population')
# We name the x-axis "Cumulative % Population".
plt.ylabel('Cumulative % Bad')
# We name the y-axis "Cumulative % Bad".
plt.title('Gini')
# We name the graph "Gini".
# Out:
# Text(0.5, 1.0, 'Gini')

# %%
Gini = AUROC * 2 - 1
# Here we calculate Gini from AUROC.
Gini
# Out:
# 0.40416429042647195

# %%
# Plot KS
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Bad'], color = 'r')
# We plot the predicted (estimated) probabilities along the x-axis and the cumulative percentage 'bad' along the y-axis,
# colored in red.
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Good'], color = 'b')
# We plot the predicted (estimated) probabilities along the x-axis and the cumulative percentage 'good' along the y-axis,
# colored in red.
plt.xlabel('Estimated Probability for being Good')
# We name the x-axis "Estimated Probability for being Good".
plt.ylabel('Cumulative %')
# We name the y-axis "Cumulative %".
plt.title('Kolmogorov-Smirnov')
# We name the graph "Kolmogorov-Smirnov".
# Out:
# Text(0.5, 1.0, 'Kolmogorov-Smirnov')

# %%
KS = max(df_actual_predicted_probs['Cumulative Perc Bad'] - df_actual_predicted_probs['Cumulative Perc Good'])
# We calculate KS from the data. It is the maximum of the difference between the cumulative percentage of 'bad'
# and the cumulative percentage of 'good'.
KS
# Out:
# 0.2962249788006473

# %% [markdown]
# # Applying the PD Model

# %% [markdown]
# ### Calculating PD of individual accounts

# %%
pd.options.display.max_columns = None
# Sets the pandas dataframe options to display all columns/ rows.

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86
# 362514                             0
# 288564                             0
# 213591                             0
# 263083                             0
# 165001                             0

# %%
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.286591            NaN
# 1                               grade:A      1.155571   2.054571e-37
# 2                               grade:B      0.912941   2.731773e-51
# 3                               grade:C      0.716389   2.225365e-37
# 4                               grade:D      0.525339   4.191192e-23
# 5                               grade:E      0.342274   3.044944e-13
# 6                               grade:F      0.152211   1.812154e-03
# 7                    home_ownership:OWN      0.093715   3.282189e-06
# 8               home_ownership:MORTGAGE      0.106218   4.428816e-17
# 9                      addr_state:NM_VA      0.036094   2.594831e-01
# 10                        addr_state:NY      0.057791   1.698910e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059826   9.726920e-03
# 12                        addr_state:CA      0.063947   2.537804e-03
# 13               addr_state:UT_KY_AZ_NJ      0.078982   1.514118e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.136947   1.151591e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.101652   6.562288e-04
# 16                  addr_state:GA_WA_OR      0.185745   3.201430e-12
# 17                     addr_state:WI_MT      0.240440   4.240665e-07
# 18                        addr_state:TX      0.222863   9.250644e-18
# 19                     addr_state:IL_CT      0.262767   2.218063e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930   2.185174e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524189   6.882691e-23
# 22     verification_status:Not Verified      0.084431   7.097765e-09
# 23  verification_status:Source Verified     -0.010562   4.316255e-01
# 24                  purpose:credit_card      0.300414   2.051002e-26
# 25           purpose:debt_consolidation      0.197167   3.172050e-14
# 26           purpose:oth__med__vacation      0.213260   6.773720e-12
# 27  purpose:major_purch__car__home_impr      0.265543   1.653427e-17
# 28                initial_list_status:w      0.054820   2.676211e-05
# 29                              term:36      0.078659   1.812804e-08
# 30                         emp_length:1      0.099202   1.301621e-04
# 31                       emp_length:2-4      0.126174   2.247723e-11
# 32                       emp_length:5-6      0.091429   1.923635e-05
# 33                       emp_length:7-9      0.061589   3.054330e-03
# 34                        emp_length:10      0.125337   1.034983e-11
# 35               mths_since_issue_d:<38      1.091989  7.307195e-189
# 36             mths_since_issue_d:38-39      0.890632  1.158310e-158
# 37             mths_since_issue_d:40-41      0.788919  1.874188e-131
# 38             mths_since_issue_d:42-48      0.587156   4.827482e-94
# 39             mths_since_issue_d:49-52      0.425050   8.032616e-44
# 40             mths_since_issue_d:53-64      0.178656   5.217626e-10
# 41             mths_since_issue_d:65-84     -0.060627   3.499544e-02
# 42                      int_rate:<9.548      0.867413   3.709293e-30
# 43                int_rate:9.548-12.025      0.540433   7.714578e-34
# 44                int_rate:12.025-15.74      0.291225   1.984920e-15
# 45                int_rate:15.74-20.281      0.103115   3.683881e-04
# 46  mths_since_earliest_cr_line:141-164      0.056445   2.316610e-02
# 47  mths_since_earliest_cr_line:165-247      0.038179   5.685032e-02
# 48  mths_since_earliest_cr_line:248-270      0.080629   2.091505e-03
# 49  mths_since_earliest_cr_line:271-352      0.122844   1.497001e-07
# 50     mths_since_earliest_cr_line:>352      0.131433   6.940027e-07
# 51                     inq_last_6mths:0      0.694467   8.171735e-18
# 52                   inq_last_6mths:1-2      0.547350   1.182933e-11
# 53                   inq_last_6mths:3-6      0.336636   3.563451e-05
# 54                   acc_now_delinq:>=1      0.235441   2.326845e-02
# 55                   annual_inc:20K-30K     -0.068937   9.947818e-02
# 56                   annual_inc:30K-40K     -0.005534   8.904890e-01
# 57                   annual_inc:40K-50K      0.089310   2.606733e-02
# 58                   annual_inc:50K-60K      0.156335   1.207766e-04
# 59                   annual_inc:60K-70K      0.231736   2.552314e-08
# 60                   annual_inc:70K-80K      0.306244   5.402130e-13
# 61                   annual_inc:80K-90K      0.380310   7.968175e-18
# 62                  annual_inc:90K-100K      0.400761   2.166493e-18
# 63                 annual_inc:100K-120K      0.479389   4.984335e-26
# 64                 annual_inc:120K-140K      0.577045   7.341082e-29
# 65                     annual_inc:>140K      0.505300   1.348163e-26
# 66                            dti:<=1.4      0.252542   2.330160e-03
# 67                          dti:1.4-3.5      0.371502   8.811998e-08
# 68                          dti:3.5-7.7      0.389219   6.677722e-11
# 69                         dti:7.7-10.5      0.324630   4.306794e-08
# 70                        dti:10.5-16.1      0.245254   1.825593e-05
# 71                        dti:16.1-20.3      0.143909   1.207483e-02
# 72                        dti:20.3-21.7      0.132743   2.711004e-02
# 73                        dti:21.7-22.4      0.097494   1.288914e-01
# 74                          dti:22.4-35      0.054607   3.354135e-01
# 75       mths_since_last_delinq:Missing      0.167530   3.993944e-04
# 76          mths_since_last_delinq:4-30      0.192270   6.766861e-05
# 77         mths_since_last_delinq:31-56      0.239036   1.034442e-06
# 78          mths_since_last_delinq:>=57      0.191775   1.379534e-04
# 79       mths_since_last_record:Missing      0.102728   2.755594e-06
# 80          mths_since_last_record:3-20      0.212815   2.358424e-02
# 81         mths_since_last_record:21-31      0.135716   9.164776e-02
# 82         mths_since_last_record:32-80      0.286677   1.251221e-18
# 83         mths_since_last_record:81-86     -0.049871   4.455653e-01

# %%
y_hat_test_proba
# Out:
# array([0.92448608, 0.84304655, 0.88550117, ..., 0.97325274, 0.95981387,
#        0.95223646])

# %% [markdown]
# ### Creating a Scorecard

# %%
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.286591            NaN
# 1                               grade:A      1.155571   2.054571e-37
# 2                               grade:B      0.912941   2.731773e-51
# 3                               grade:C      0.716389   2.225365e-37
# 4                               grade:D      0.525339   4.191192e-23
# 5                               grade:E      0.342274   3.044944e-13
# 6                               grade:F      0.152211   1.812154e-03
# 7                    home_ownership:OWN      0.093715   3.282189e-06
# 8               home_ownership:MORTGAGE      0.106218   4.428816e-17
# 9                      addr_state:NM_VA      0.036094   2.594831e-01
# 10                        addr_state:NY      0.057791   1.698910e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059826   9.726920e-03
# 12                        addr_state:CA      0.063947   2.537804e-03
# 13               addr_state:UT_KY_AZ_NJ      0.078982   1.514118e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.136947   1.151591e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.101652   6.562288e-04
# 16                  addr_state:GA_WA_OR      0.185745   3.201430e-12
# 17                     addr_state:WI_MT      0.240440   4.240665e-07
# 18                        addr_state:TX      0.222863   9.250644e-18
# 19                     addr_state:IL_CT      0.262767   2.218063e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930   2.185174e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524189   6.882691e-23
# 22     verification_status:Not Verified      0.084431   7.097765e-09
# 23  verification_status:Source Verified     -0.010562   4.316255e-01
# 24                  purpose:credit_card      0.300414   2.051002e-26
# 25           purpose:debt_consolidation      0.197167   3.172050e-14
# 26           purpose:oth__med__vacation      0.213260   6.773720e-12
# 27  purpose:major_purch__car__home_impr      0.265543   1.653427e-17
# 28                initial_list_status:w      0.054820   2.676211e-05
# 29                              term:36      0.078659   1.812804e-08
# 30                         emp_length:1      0.099202   1.301621e-04
# 31                       emp_length:2-4      0.126174   2.247723e-11
# 32                       emp_length:5-6      0.091429   1.923635e-05
# 33                       emp_length:7-9      0.061589   3.054330e-03
# 34                        emp_length:10      0.125337   1.034983e-11
# 35               mths_since_issue_d:<38      1.091989  7.307195e-189
# 36             mths_since_issue_d:38-39      0.890632  1.158310e-158
# 37             mths_since_issue_d:40-41      0.788919  1.874188e-131
# 38             mths_since_issue_d:42-48      0.587156   4.827482e-94
# 39             mths_since_issue_d:49-52      0.425050   8.032616e-44
# 40             mths_since_issue_d:53-64      0.178656   5.217626e-10
# 41             mths_since_issue_d:65-84     -0.060627   3.499544e-02
# 42                      int_rate:<9.548      0.867413   3.709293e-30
# 43                int_rate:9.548-12.025      0.540433   7.714578e-34
# 44                int_rate:12.025-15.74      0.291225   1.984920e-15
# 45                int_rate:15.74-20.281      0.103115   3.683881e-04
# 46  mths_since_earliest_cr_line:141-164      0.056445   2.316610e-02
# 47  mths_since_earliest_cr_line:165-247      0.038179   5.685032e-02
# 48  mths_since_earliest_cr_line:248-270      0.080629   2.091505e-03
# 49  mths_since_earliest_cr_line:271-352      0.122844   1.497001e-07
# 50     mths_since_earliest_cr_line:>352      0.131433   6.940027e-07
# 51                     inq_last_6mths:0      0.694467   8.171735e-18
# 52                   inq_last_6mths:1-2      0.547350   1.182933e-11
# 53                   inq_last_6mths:3-6      0.336636   3.563451e-05
# 54                   acc_now_delinq:>=1      0.235441   2.326845e-02
# 55                   annual_inc:20K-30K     -0.068937   9.947818e-02
# 56                   annual_inc:30K-40K     -0.005534   8.904890e-01
# 57                   annual_inc:40K-50K      0.089310   2.606733e-02
# 58                   annual_inc:50K-60K      0.156335   1.207766e-04
# 59                   annual_inc:60K-70K      0.231736   2.552314e-08
# 60                   annual_inc:70K-80K      0.306244   5.402130e-13
# 61                   annual_inc:80K-90K      0.380310   7.968175e-18
# 62                  annual_inc:90K-100K      0.400761   2.166493e-18
# 63                 annual_inc:100K-120K      0.479389   4.984335e-26
# 64                 annual_inc:120K-140K      0.577045   7.341082e-29
# 65                     annual_inc:>140K      0.505300   1.348163e-26
# 66                            dti:<=1.4      0.252542   2.330160e-03
# 67                          dti:1.4-3.5      0.371502   8.811998e-08
# 68                          dti:3.5-7.7      0.389219   6.677722e-11
# 69                         dti:7.7-10.5      0.324630   4.306794e-08
# 70                        dti:10.5-16.1      0.245254   1.825593e-05
# 71                        dti:16.1-20.3      0.143909   1.207483e-02
# 72                        dti:20.3-21.7      0.132743   2.711004e-02
# 73                        dti:21.7-22.4      0.097494   1.288914e-01
# 74                          dti:22.4-35      0.054607   3.354135e-01
# 75       mths_since_last_delinq:Missing      0.167530   3.993944e-04
# 76          mths_since_last_delinq:4-30      0.192270   6.766861e-05
# 77         mths_since_last_delinq:31-56      0.239036   1.034442e-06
# 78          mths_since_last_delinq:>=57      0.191775   1.379534e-04
# 79       mths_since_last_record:Missing      0.102728   2.755594e-06
# 80          mths_since_last_record:3-20      0.212815   2.358424e-02
# 81         mths_since_last_record:21-31      0.135716   9.164776e-02
# 82         mths_since_last_record:32-80      0.286677   1.251221e-18
# 83         mths_since_last_record:81-86     -0.049871   4.455653e-01

# %%
ref_categories
# Out:
# ['grade:G',
#  'home_ownership:RENT_OTHER_NONE_ANY',
#  'addr_state:ND_NE_IA_NV_FL_HI_AL',
#  'verification_status:Verified',
#  'purpose:educ__sm_b__wedd__ren_en__mov__house',
#  'initial_list_status:f',
#  'term:60',
#  'emp_length:0',
#  'mths_since_issue_d:>84',
#  'int_rate:>20.281',
#  'mths_since_earliest_cr_line:<140',
#  'inq_last_6mths:>6',
#  'acc_now_delinq:0',
#  'annual_inc:<20K',
#  'dti:>35',
#  'mths_since_last_delinq:0-3',
#  'mths_since_last_record:0-2']

# %%
df_ref_categories = pd.DataFrame(ref_categories, columns = ['Feature name'])
# We create a new dataframe with one column. Its values are the values from the 'reference_categories' list.
# We name it 'Feature name'.
df_ref_categories['Coefficients'] = 0
# We create a second column, called 'Coefficients', which contains only 0 values.
df_ref_categories['p_values'] = np.nan
# We create a third column, called 'p_values', with contains only NaN values.
df_ref_categories
# Out:
#                                     Feature name  Coefficients  p_values
# 0                                        grade:G             0       NaN
# 1             home_ownership:RENT_OTHER_NONE_ANY             0       NaN
# 2                addr_state:ND_NE_IA_NV_FL_HI_AL             0       NaN
# 3                   verification_status:Verified             0       NaN
# 4   purpose:educ__sm_b__wedd__ren_en__mov__house             0       NaN
# 5                          initial_list_status:f             0       NaN
# 6                                        term:60             0       NaN
# 7                                   emp_length:0             0       NaN
# 8                         mths_since_issue_d:>84             0       NaN
# 9                               int_rate:>20.281             0       NaN
# 10              mths_since_earliest_cr_line:<140             0       NaN
# 11                             inq_last_6mths:>6             0       NaN
# 12                              acc_now_delinq:0             0       NaN
# 13                               annual_inc:<20K             0       NaN
# 14                                       dti:>35             0       NaN
# 15                    mths_since_last_delinq:0-3             0       NaN
# 16                    mths_since_last_record:0-2             0       NaN

# %%
df_scorecard = pd.concat([summary_table, df_ref_categories])
# Concatenates two dataframes.
df_scorecard = df_scorecard.reset_index()
# We reset the index of a dataframe.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values
# 0              NaN
# 1     2.054571e-37
# 2     2.731773e-51
# 3     2.225365e-37
# 4     4.191192e-23
# 5     3.044944e-13
# 6     1.812154e-03
# 7     3.282189e-06
# 8     4.428816e-17
# 9     2.594831e-01
# 10    1.698910e-02
# 11    9.726920e-03
# 12    2.537804e-03
# 13    1.514118e-03
# 14    1.151591e-09
# 15    6.562288e-04
# 16    3.201430e-12
# 17    4.240665e-07
# 18    9.250644e-18
# 19    2.218063e-19
# 20    2.185174e-25
# 21    6.882691e-23
# 22    7.097765e-09
# 23    4.316255e-01
# 24    2.051002e-26
# 25    3.172050e-14
# 26    6.773720e-12
# 27    1.653427e-17
# 28    2.676211e-05
# 29    1.812804e-08
# 30    1.301621e-04
# 31    2.247723e-11
# 32    1.923635e-05
# 33    3.054330e-03
# 34    1.034983e-11
# 35   7.307195e-189
# 36   1.158310e-158
# 37   1.874188e-131
# 38    4.827482e-94
# 39    8.032616e-44
# 40    5.217626e-10
# 41    3.499544e-02
# 42    3.709293e-30
# 43    7.714578e-34
# 44    1.984920e-15
# 45    3.683881e-04
# 46    2.316610e-02
# 47    5.685032e-02
# 48    2.091505e-03
# 49    1.497001e-07
# 50    6.940027e-07
# 51    8.171735e-18
# 52    1.182933e-11
# 53    3.563451e-05
# 54    2.326845e-02
# 55    9.947818e-02
# 56    8.904890e-01
# 57    2.606733e-02
# 58    1.207766e-04
# 59    2.552314e-08
# 60    5.402130e-13
# 61    7.968175e-18
# 62    2.166493e-18
# 63    4.984335e-26
# 64    7.341082e-29
# 65    1.348163e-26
# 66    2.330160e-03
# 67    8.811998e-08
# 68    6.677722e-11
# 69    4.306794e-08
# 70    1.825593e-05
# 71    1.207483e-02
# 72    2.711004e-02
# 73    1.288914e-01
# 74    3.354135e-01
# 75    3.993944e-04
# 76    6.766861e-05
# 77    1.034442e-06
# 78    1.379534e-04
# 79    2.755594e-06
# 80    2.358424e-02
# 81    9.164776e-02
# 82    1.251221e-18
# 83    4.455653e-01
# 84             NaN
# 85             NaN
# 86             NaN
# 87             NaN
# 88             NaN
# 89             NaN
# 90             NaN
# 91             NaN
# 92             NaN
# 93             NaN
# 94             NaN
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
# 100            NaN

# %%
df_scorecard['Original feature name'] = df_scorecard['Feature name'].str.split(':').str[0]
# We create a new column, called 'Original feature name', which contains the value of the 'Feature name' column,
# up to the column symbol.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name
# 0              NaN                    Intercept
# 1     2.054571e-37                        grade
# 2     2.731773e-51                        grade
# 3     2.225365e-37                        grade
# 4     4.191192e-23                        grade
# 5     3.044944e-13                        grade
# 6     1.812154e-03                        grade
# 7     3.282189e-06               home_ownership
# 8     4.428816e-17               home_ownership
# 9     2.594831e-01                   addr_state
# 10    1.698910e-02                   addr_state
# 11    9.726920e-03                   addr_state
# 12    2.537804e-03                   addr_state
# 13    1.514118e-03                   addr_state
# 14    1.151591e-09                   addr_state
# 15    6.562288e-04                   addr_state
# 16    3.201430e-12                   addr_state
# 17    4.240665e-07                   addr_state
# 18    9.250644e-18                   addr_state
# 19    2.218063e-19                   addr_state
# 20    2.185174e-25                   addr_state
# 21    6.882691e-23                   addr_state
# 22    7.097765e-09          verification_status
# 23    4.316255e-01          verification_status
# 24    2.051002e-26                      purpose
# 25    3.172050e-14                      purpose
# 26    6.773720e-12                      purpose
# 27    1.653427e-17                      purpose
# 28    2.676211e-05          initial_list_status
# 29    1.812804e-08                         term
# 30    1.301621e-04                   emp_length
# 31    2.247723e-11                   emp_length
# 32    1.923635e-05                   emp_length
# 33    3.054330e-03                   emp_length
# 34    1.034983e-11                   emp_length
# 35   7.307195e-189           mths_since_issue_d
# 36   1.158310e-158           mths_since_issue_d
# 37   1.874188e-131           mths_since_issue_d
# 38    4.827482e-94           mths_since_issue_d
# 39    8.032616e-44           mths_since_issue_d
# 40    5.217626e-10           mths_since_issue_d
# 41    3.499544e-02           mths_since_issue_d
# 42    3.709293e-30                     int_rate
# 43    7.714578e-34                     int_rate
# 44    1.984920e-15                     int_rate
# 45    3.683881e-04                     int_rate
# 46    2.316610e-02  mths_since_earliest_cr_line
# 47    5.685032e-02  mths_since_earliest_cr_line
# 48    2.091505e-03  mths_since_earliest_cr_line
# 49    1.497001e-07  mths_since_earliest_cr_line
# 50    6.940027e-07  mths_since_earliest_cr_line
# 51    8.171735e-18               inq_last_6mths
# 52    1.182933e-11               inq_last_6mths
# 53    3.563451e-05               inq_last_6mths
# 54    2.326845e-02               acc_now_delinq
# 55    9.947818e-02                   annual_inc
# 56    8.904890e-01                   annual_inc
# 57    2.606733e-02                   annual_inc
# 58    1.207766e-04                   annual_inc
# 59    2.552314e-08                   annual_inc
# 60    5.402130e-13                   annual_inc
# 61    7.968175e-18                   annual_inc
# 62    2.166493e-18                   annual_inc
# 63    4.984335e-26                   annual_inc
# 64    7.341082e-29                   annual_inc
# 65    1.348163e-26                   annual_inc
# 66    2.330160e-03                          dti
# 67    8.811998e-08                          dti
# 68    6.677722e-11                          dti
# 69    4.306794e-08                          dti
# 70    1.825593e-05                          dti
# 71    1.207483e-02                          dti
# 72    2.711004e-02                          dti
# 73    1.288914e-01                          dti
# 74    3.354135e-01                          dti
# 75    3.993944e-04       mths_since_last_delinq
# 76    6.766861e-05       mths_since_last_delinq
# 77    1.034442e-06       mths_since_last_delinq
# 78    1.379534e-04       mths_since_last_delinq
# 79    2.755594e-06       mths_since_last_record
# 80    2.358424e-02       mths_since_last_record
# 81    9.164776e-02       mths_since_last_record
# 82    1.251221e-18       mths_since_last_record
# 83    4.455653e-01       mths_since_last_record
# 84             NaN                        grade
# 85             NaN               home_ownership
# 86             NaN                   addr_state
# 87             NaN          verification_status
# 88             NaN                      purpose
# 89             NaN          initial_list_status
# 90             NaN                         term
# 91             NaN                   emp_length
# 92             NaN           mths_since_issue_d
# 93             NaN                     int_rate
# 94             NaN  mths_since_earliest_cr_line
# 95             NaN               inq_last_6mths
# 96             NaN               acc_now_delinq
# 97             NaN                   annual_inc
# 98             NaN                          dti
# 99             NaN       mths_since_last_delinq
# 100            NaN       mths_since_last_record

# %%
min_score = 300
max_score = 850

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].min()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Out:
# Original feature name
# Intercept                     -1.286591
# acc_now_delinq                 0.000000
# addr_state                     0.000000
# annual_inc                    -0.068937
# dti                            0.000000
# emp_length                     0.000000
# grade                          0.000000
# home_ownership                 0.000000
# initial_list_status            0.000000
# inq_last_6mths                 0.000000
# int_rate                       0.000000
# mths_since_earliest_cr_line    0.000000
# mths_since_issue_d            -0.060627
# mths_since_last_delinq         0.000000
# mths_since_last_record        -0.049871
# purpose                        0.000000
# term                           0.000000
# verification_status           -0.010562
# Name: Coefficients, dtype: float64

# %%
min_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].min().sum()
# Up to the 'min()' method everything is the same as in te line above.
# Then, we aggregate further and sum all the minimum values.
min_sum_coef
# Out:
# -1.4765871037308957

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].max()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Out:
# Original feature name
# Intercept                     -1.286591
# acc_now_delinq                 0.235441
# addr_state                     0.524189
# annual_inc                     0.577045
# dti                            0.389219
# emp_length                     0.126174
# grade                          1.155571
# home_ownership                 0.106218
# initial_list_status            0.054820
# inq_last_6mths                 0.694467
# int_rate                       0.867413
# mths_since_earliest_cr_line    0.131433
# mths_since_issue_d             1.091989
# mths_since_last_delinq         0.239036
# mths_since_last_record         0.286677
# purpose                        0.300414
# term                           0.078659
# verification_status            0.084431
# Name: Coefficients, dtype: float64

# %%
max_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].max().sum()
# Up to the 'min()' method everything is the same as in te line above.
# Then, we aggregate further and sum all the maximum values.
max_sum_coef
# Out:
# 5.656605903642922

# %%
df_scorecard['Score - Calculation'] = df_scorecard['Coefficients'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
# We multiply the value of the 'Coefficients' column by the ratio of the differences between
# maximum score and minimum score and maximum sum of coefficients and minimum sum of cefficients.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation
# 0              NaN                    Intercept           -99.201713
# 1     2.054571e-37                        grade            89.099526
# 2     2.731773e-51                        grade            70.391665
# 3     2.225365e-37                        grade            55.236655
# 4     4.191192e-23                        grade            40.505913
# 5     3.044944e-13                        grade            26.390835
# 6     1.812154e-03                        grade            11.736093
# 7     3.282189e-06               home_ownership             7.225848
# 8     4.428816e-17               home_ownership             8.189905
# 9     2.594831e-01                   addr_state             2.783010
# 10    1.698910e-02                   addr_state             4.455972
# 11    9.726920e-03                   addr_state             4.612878
# 12    2.537804e-03                   addr_state             4.930605
# 13    1.514118e-03                   addr_state             6.089840
# 14    1.151591e-09                   addr_state            10.559195
# 15    6.562288e-04                   addr_state             7.837847
# 16    3.201430e-12                   addr_state            14.321715
# 17    4.240665e-07                   addr_state            18.538930
# 18    9.250644e-18                   addr_state            17.183674
# 19    2.218063e-19                   addr_state            20.260439
# 20    2.185174e-25                   addr_state            24.745096
# 21    6.882691e-23                   addr_state            40.417198
# 22    7.097765e-09          verification_status             6.510023
# 23    4.316255e-01          verification_status            -0.814360
# 24    2.051002e-26                      purpose            23.163202
# 25    3.172050e-14                      purpose            15.202433
# 26    6.773720e-12                      purpose            16.443284
# 27    1.653427e-17                      purpose            20.474549
# 28    2.676211e-05          initial_list_status             4.226837
# 29    1.812804e-08                         term             6.064951
# 30    1.301621e-04                   emp_length             7.648900
# 31    2.247723e-11                   emp_length             9.728584
# 32    1.923635e-05                   emp_length             7.049576
# 33    3.054330e-03                   emp_length             4.748798
# 34    1.034983e-11                   emp_length             9.663994
# 35   7.307195e-189           mths_since_issue_d            84.197083
# 36   1.158310e-158           mths_since_issue_d            68.671600
# 37   1.874188e-131           mths_since_issue_d            60.829028
# 38    4.827482e-94           mths_since_issue_d            45.272290
# 39    8.032616e-44           mths_since_issue_d            32.773185
# 40    5.217626e-10           mths_since_issue_d            13.775148
# 41    3.499544e-02           mths_since_issue_d            -4.674590
# 42    3.709293e-30                     int_rate            66.881253
# 43    7.714578e-34                     int_rate            41.669735
# 44    1.984920e-15                     int_rate            22.454701
# 45    3.683881e-04                     int_rate             7.950618
# 46    2.316610e-02  mths_since_earliest_cr_line             4.352163
# 47    5.685032e-02  mths_since_earliest_cr_line             2.943733
# 48    2.091505e-03  mths_since_earliest_cr_line             6.216878
# 49    1.497001e-07  mths_since_earliest_cr_line             9.471809
# 50    6.940027e-07  mths_since_earliest_cr_line            10.134031
# 51    8.171735e-18               inq_last_6mths            53.546431
# 52    1.182933e-11               inq_last_6mths            42.203025
# 53    3.563451e-05               inq_last_6mths            25.956054
# 54    2.326845e-02               acc_now_delinq            18.153542
# 55    9.947818e-02                   annual_inc            -5.315306
# 56    8.904890e-01                   annual_inc            -0.426695
# 57    2.606733e-02                   annual_inc             6.886209
# 58    1.207766e-04                   annual_inc            12.054099
# 59    2.552314e-08                   annual_inc            17.867862
# 60    5.402130e-13                   annual_inc            23.612709
# 61    7.968175e-18                   annual_inc            29.323581
# 62    2.166493e-18                   annual_inc            30.900399
# 63    4.984335e-26                   annual_inc            36.962987
# 64    7.341082e-29                   annual_inc            44.492681
# 65    1.348163e-26                   annual_inc            38.960821
# 66    2.330160e-03                          dti            19.472109
# 67    8.811998e-08                          dti            28.644416
# 68    6.677722e-11                          dti            30.010455
# 69    4.306794e-08                          dti            25.030410
# 70    1.825593e-05                          dti            18.910181
# 71    1.207483e-02                          dti            11.095976
# 72    2.711004e-02                          dti            10.235084
# 73    1.288914e-01                          dti             7.517242
# 74    3.354135e-01                          dti             4.210406
# 75    3.993944e-04       mths_since_last_delinq            12.917262
# 76    6.766861e-05       mths_since_last_delinq            14.824816
# 77    1.034442e-06       mths_since_last_delinq            18.430709
# 78    1.379534e-04       mths_since_last_delinq            14.786663
# 79    2.755594e-06       mths_since_last_record             7.920808
# 80    2.358424e-02       mths_since_last_record            16.408928
# 81    9.164776e-02       mths_since_last_record            10.464310
# 82    1.251221e-18       mths_since_last_record            22.104057
# 83    4.455653e-01       mths_since_last_record            -3.845277
# 84             NaN                        grade             0.000000
# 85             NaN               home_ownership             0.000000
# 86             NaN                   addr_state             0.000000
# 87             NaN          verification_status             0.000000
# 88             NaN                      purpose             0.000000
# 89             NaN          initial_list_status             0.000000
# 90             NaN                         term             0.000000
# 91             NaN                   emp_length             0.000000
# 92             NaN           mths_since_issue_d             0.000000
# 93             NaN                     int_rate             0.000000
# 94             NaN  mths_since_earliest_cr_line             0.000000
# 95             NaN               inq_last_6mths             0.000000
# 96             NaN               acc_now_delinq             0.000000
# 97             NaN                   annual_inc             0.000000
# 98             NaN                          dti             0.000000
# 99             NaN       mths_since_last_delinq             0.000000
# 100            NaN       mths_since_last_record             0.000000

# %%
df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
# We divide the difference of the value of the 'Coefficients' column and the minimum sum of coefficients by
# the difference of the maximum sum of coefficients and the minimum sum of coefficients.
# Then, we multiply that by the difference between the maximum score and the minimum score.
# Then, we add minimum score. 
df_scorecard
# Out:
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_38239/1410049194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation
# 0              NaN                    Intercept           314.649532
# 1     2.054571e-37                        grade            89.099526
# 2     2.731773e-51                        grade            70.391665
# 3     2.225365e-37                        grade            55.236655
# 4     4.191192e-23                        grade            40.505913
# 5     3.044944e-13                        grade            26.390835
# 6     1.812154e-03                        grade            11.736093
# 7     3.282189e-06               home_ownership             7.225848
# 8     4.428816e-17               home_ownership             8.189905
# 9     2.594831e-01                   addr_state             2.783010
# 10    1.698910e-02                   addr_state             4.455972
# 11    9.726920e-03                   addr_state             4.612878
# 12    2.537804e-03                   addr_state             4.930605
# 13    1.514118e-03                   addr_state             6.089840
# 14    1.151591e-09                   addr_state            10.559195
# 15    6.562288e-04                   addr_state             7.837847
# 16    3.201430e-12                   addr_state            14.321715
# 17    4.240665e-07                   addr_state            18.538930
# 18    9.250644e-18                   addr_state            17.183674
# 19    2.218063e-19                   addr_state            20.260439
# 20    2.185174e-25                   addr_state            24.745096
# 21    6.882691e-23                   addr_state            40.417198
# 22    7.097765e-09          verification_status             6.510023
# 23    4.316255e-01          verification_status            -0.814360
# 24    2.051002e-26                      purpose            23.163202
# 25    3.172050e-14                      purpose            15.202433
# 26    6.773720e-12                      purpose            16.443284
# 27    1.653427e-17                      purpose            20.474549
# 28    2.676211e-05          initial_list_status             4.226837
# 29    1.812804e-08                         term             6.064951
# 30    1.301621e-04                   emp_length             7.648900
# 31    2.247723e-11                   emp_length             9.728584
# 32    1.923635e-05                   emp_length             7.049576
# 33    3.054330e-03                   emp_length             4.748798
# 34    1.034983e-11                   emp_length             9.663994
# 35   7.307195e-189           mths_since_issue_d            84.197083
# 36   1.158310e-158           mths_since_issue_d            68.671600
# 37   1.874188e-131           mths_since_issue_d            60.829028
# 38    4.827482e-94           mths_since_issue_d            45.272290
# 39    8.032616e-44           mths_since_issue_d            32.773185
# 40    5.217626e-10           mths_since_issue_d            13.775148
# 41    3.499544e-02           mths_since_issue_d            -4.674590
# 42    3.709293e-30                     int_rate            66.881253
# 43    7.714578e-34                     int_rate            41.669735
# 44    1.984920e-15                     int_rate            22.454701
# 45    3.683881e-04                     int_rate             7.950618
# 46    2.316610e-02  mths_since_earliest_cr_line             4.352163
# 47    5.685032e-02  mths_since_earliest_cr_line             2.943733
# 48    2.091505e-03  mths_since_earliest_cr_line             6.216878
# 49    1.497001e-07  mths_since_earliest_cr_line             9.471809
# 50    6.940027e-07  mths_since_earliest_cr_line            10.134031
# 51    8.171735e-18               inq_last_6mths            53.546431
# 52    1.182933e-11               inq_last_6mths            42.203025
# 53    3.563451e-05               inq_last_6mths            25.956054
# 54    2.326845e-02               acc_now_delinq            18.153542
# 55    9.947818e-02                   annual_inc            -5.315306
# 56    8.904890e-01                   annual_inc            -0.426695
# 57    2.606733e-02                   annual_inc             6.886209
# 58    1.207766e-04                   annual_inc            12.054099
# 59    2.552314e-08                   annual_inc            17.867862
# 60    5.402130e-13                   annual_inc            23.612709
# 61    7.968175e-18                   annual_inc            29.323581
# 62    2.166493e-18                   annual_inc            30.900399
# 63    4.984335e-26                   annual_inc            36.962987
# 64    7.341082e-29                   annual_inc            44.492681
# 65    1.348163e-26                   annual_inc            38.960821
# 66    2.330160e-03                          dti            19.472109
# 67    8.811998e-08                          dti            28.644416
# 68    6.677722e-11                          dti            30.010455
# 69    4.306794e-08                          dti            25.030410
# 70    1.825593e-05                          dti            18.910181
# 71    1.207483e-02                          dti            11.095976
# 72    2.711004e-02                          dti            10.235084
# 73    1.288914e-01                          dti             7.517242
# 74    3.354135e-01                          dti             4.210406
# 75    3.993944e-04       mths_since_last_delinq            12.917262
# 76    6.766861e-05       mths_since_last_delinq            14.824816
# 77    1.034442e-06       mths_since_last_delinq            18.430709
# 78    1.379534e-04       mths_since_last_delinq            14.786663
# 79    2.755594e-06       mths_since_last_record             7.920808
# 80    2.358424e-02       mths_since_last_record            16.408928
# 81    9.164776e-02       mths_since_last_record            10.464310
# 82    1.251221e-18       mths_since_last_record            22.104057
# 83    4.455653e-01       mths_since_last_record            -3.845277
# 84             NaN                        grade             0.000000
# 85             NaN               home_ownership             0.000000
# 86             NaN                   addr_state             0.000000
# 87             NaN          verification_status             0.000000
# 88             NaN                      purpose             0.000000
# 89             NaN          initial_list_status             0.000000
# 90             NaN                         term             0.000000
# 91             NaN                   emp_length             0.000000
# 92             NaN           mths_since_issue_d             0.000000
# 93             NaN                     int_rate             0.000000
# 94             NaN  mths_since_earliest_cr_line             0.000000
# 95             NaN               inq_last_6mths             0.000000
# 96             NaN               acc_now_delinq             0.000000
# 97             NaN                   annual_inc             0.000000
# 98             NaN                          dti             0.000000
# 99             NaN       mths_since_last_delinq             0.000000
# 100            NaN       mths_since_last_record             0.000000

# %%
df_scorecard['Score - Preliminary'] = df_scorecard['Score - Calculation'].round()
# We round the values of the 'Score - Calculation' column.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           314.649532
# 1     2.054571e-37                        grade            89.099526
# 2     2.731773e-51                        grade            70.391665
# 3     2.225365e-37                        grade            55.236655
# 4     4.191192e-23                        grade            40.505913
# 5     3.044944e-13                        grade            26.390835
# 6     1.812154e-03                        grade            11.736093
# 7     3.282189e-06               home_ownership             7.225848
# 8     4.428816e-17               home_ownership             8.189905
# 9     2.594831e-01                   addr_state             2.783010
# 10    1.698910e-02                   addr_state             4.455972
# 11    9.726920e-03                   addr_state             4.612878
# 12    2.537804e-03                   addr_state             4.930605
# 13    1.514118e-03                   addr_state             6.089840
# 14    1.151591e-09                   addr_state            10.559195
# 15    6.562288e-04                   addr_state             7.837847
# 16    3.201430e-12                   addr_state            14.321715
# 17    4.240665e-07                   addr_state            18.538930
# 18    9.250644e-18                   addr_state            17.183674
# 19    2.218063e-19                   addr_state            20.260439
# 20    2.185174e-25                   addr_state            24.745096
# 21    6.882691e-23                   addr_state            40.417198
# 22    7.097765e-09          verification_status             6.510023
# 23    4.316255e-01          verification_status            -0.814360
# 24    2.051002e-26                      purpose            23.163202
# 25    3.172050e-14                      purpose            15.202433
# 26    6.773720e-12                      purpose            16.443284
# 27    1.653427e-17                      purpose            20.474549
# 28    2.676211e-05          initial_list_status             4.226837
# 29    1.812804e-08                         term             6.064951
# 30    1.301621e-04                   emp_length             7.648900
# 31    2.247723e-11                   emp_length             9.728584
# 32    1.923635e-05                   emp_length             7.049576
# 33    3.054330e-03                   emp_length             4.748798
# 34    1.034983e-11                   emp_length             9.663994
# 35   7.307195e-189           mths_since_issue_d            84.197083
# 36   1.158310e-158           mths_since_issue_d            68.671600
# 37   1.874188e-131           mths_since_issue_d            60.829028
# 38    4.827482e-94           mths_since_issue_d            45.272290
# 39    8.032616e-44           mths_since_issue_d            32.773185
# 40    5.217626e-10           mths_since_issue_d            13.775148
# 41    3.499544e-02           mths_since_issue_d            -4.674590
# 42    3.709293e-30                     int_rate            66.881253
# 43    7.714578e-34                     int_rate            41.669735
# 44    1.984920e-15                     int_rate            22.454701
# 45    3.683881e-04                     int_rate             7.950618
# 46    2.316610e-02  mths_since_earliest_cr_line             4.352163
# 47    5.685032e-02  mths_since_earliest_cr_line             2.943733
# 48    2.091505e-03  mths_since_earliest_cr_line             6.216878
# 49    1.497001e-07  mths_since_earliest_cr_line             9.471809
# 50    6.940027e-07  mths_since_earliest_cr_line            10.134031
# 51    8.171735e-18               inq_last_6mths            53.546431
# 52    1.182933e-11               inq_last_6mths            42.203025
# 53    3.563451e-05               inq_last_6mths            25.956054
# 54    2.326845e-02               acc_now_delinq            18.153542
# 55    9.947818e-02                   annual_inc            -5.315306
# 56    8.904890e-01                   annual_inc            -0.426695
# 57    2.606733e-02                   annual_inc             6.886209
# 58    1.207766e-04                   annual_inc            12.054099
# 59    2.552314e-08                   annual_inc            17.867862
# 60    5.402130e-13                   annual_inc            23.612709
# 61    7.968175e-18                   annual_inc            29.323581
# 62    2.166493e-18                   annual_inc            30.900399
# 63    4.984335e-26                   annual_inc            36.962987
# 64    7.341082e-29                   annual_inc            44.492681
# 65    1.348163e-26                   annual_inc            38.960821
# 66    2.330160e-03                          dti            19.472109
# 67    8.811998e-08                          dti            28.644416
# 68    6.677722e-11                          dti            30.010455
# 69    4.306794e-08                          dti            25.030410
# 70    1.825593e-05                          dti            18.910181
# 71    1.207483e-02                          dti            11.095976
# 72    2.711004e-02                          dti            10.235084
# 73    1.288914e-01                          dti             7.517242
# 74    3.354135e-01                          dti             4.210406
# 75    3.993944e-04       mths_since_last_delinq            12.917262
# 76    6.766861e-05       mths_since_last_delinq            14.824816
# 77    1.034442e-06       mths_since_last_delinq            18.430709
# 78    1.379534e-04       mths_since_last_delinq            14.786663
# 79    2.755594e-06       mths_since_last_record             7.920808
# 80    2.358424e-02       mths_since_last_record            16.408928
# 81    9.164776e-02       mths_since_last_record            10.464310
# 82    1.251221e-18       mths_since_last_record            22.104057
# 83    4.455653e-01       mths_since_last_record            -3.845277
# 84             NaN                        grade             0.000000
# 85             NaN               home_ownership             0.000000
# 86             NaN                   addr_state             0.000000
# 87             NaN          verification_status             0.000000
# 88             NaN                      purpose             0.000000
# 89             NaN          initial_list_status             0.000000
# 90             NaN                         term             0.000000
# 91             NaN                   emp_length             0.000000
# 92             NaN           mths_since_issue_d             0.000000
# 93             NaN                     int_rate             0.000000
# 94             NaN  mths_since_earliest_cr_line             0.000000
# 95             NaN               inq_last_6mths             0.000000
# 96             NaN               acc_now_delinq             0.000000
# 97             NaN                   annual_inc             0.000000
# 98             NaN                          dti             0.000000
# 99             NaN       mths_since_last_delinq             0.000000
# 100            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary
# 0                  315.0
# 1                   89.0
# 2                   70.0
# 3                   55.0
# 4                   41.0
# 5                   26.0
# 6                   12.0
# 7                    7.0
# 8                    8.0
# 9                    3.0
# 10                   4.0
# 11                   5.0
# 12                   5.0
# 13                   6.0
# 14                  11.0
# 15                   8.0
# 16                  14.0
# 17                  19.0
# 18                  17.0
# 19                  20.0
# 20                  25.0
# 21                  40.0
# 22                   7.0
# 23                  -1.0
# 24                  23.0
# 25                  15.0
# 26                  16.0
# 27                  20.0
# 28                   4.0
# 29                   6.0
# 30                   8.0
# 31                  10.0
# 32                   7.0
# 33                   5.0
# 34                  10.0
# 35                  84.0
# 36                  69.0
# 37                  61.0
# 38                  45.0
# 39                  33.0
# 40                  14.0
# 41                  -5.0
# 42                  67.0
# 43                  42.0
# 44                  22.0
# 45                   8.0
# 46                   4.0
# 47                   3.0
# 48                   6.0
# 49                   9.0
# 50                  10.0
# 51                  54.0
# 52                  42.0
# 53                  26.0
# 54                  18.0
# 55                  -5.0
# 56                  -0.0
# 57                   7.0
# 58                  12.0
# 59                  18.0
# 60                  24.0
# 61                  29.0
# 62                  31.0
# 63                  37.0
# 64                  44.0
# 65                  39.0
# 66                  19.0
# 67                  29.0
# 68                  30.0
# 69                  25.0
# 70                  19.0
# 71                  11.0
# 72                  10.0
# 73                   8.0
# 74                   4.0
# 75                  13.0
# 76                  15.0
# 77                  18.0
# 78                  15.0
# 79                   8.0
# 80                  16.0
# 81                  10.0
# 82                  22.0
# 83                  -4.0
# 84                   0.0
# 85                   0.0
# 86                   0.0
# 87                   0.0
# 88                   0.0
# 89                   0.0
# 90                   0.0
# 91                   0.0
# 92                   0.0
# 93                   0.0
# 94                   0.0
# 95                   0.0
# 96                   0.0
# 97                   0.0
# 98                   0.0
# 99                   0.0
# 100                  0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].min().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Sums all minimum values.
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].max().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Sums all maximum values.
max_sum_score_prel
# Out:
# 849.0

# %%
# One has to be subtracted from the maximum score for one original variable. Which one? We'll evaluate based on differences.

# %%
df_scorecard['Difference'] = df_scorecard['Score - Preliminary'] - df_scorecard['Score - Calculation']
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           314.649532
# 1     2.054571e-37                        grade            89.099526
# 2     2.731773e-51                        grade            70.391665
# 3     2.225365e-37                        grade            55.236655
# 4     4.191192e-23                        grade            40.505913
# 5     3.044944e-13                        grade            26.390835
# 6     1.812154e-03                        grade            11.736093
# 7     3.282189e-06               home_ownership             7.225848
# 8     4.428816e-17               home_ownership             8.189905
# 9     2.594831e-01                   addr_state             2.783010
# 10    1.698910e-02                   addr_state             4.455972
# 11    9.726920e-03                   addr_state             4.612878
# 12    2.537804e-03                   addr_state             4.930605
# 13    1.514118e-03                   addr_state             6.089840
# 14    1.151591e-09                   addr_state            10.559195
# 15    6.562288e-04                   addr_state             7.837847
# 16    3.201430e-12                   addr_state            14.321715
# 17    4.240665e-07                   addr_state            18.538930
# 18    9.250644e-18                   addr_state            17.183674
# 19    2.218063e-19                   addr_state            20.260439
# 20    2.185174e-25                   addr_state            24.745096
# 21    6.882691e-23                   addr_state            40.417198
# 22    7.097765e-09          verification_status             6.510023
# 23    4.316255e-01          verification_status            -0.814360
# 24    2.051002e-26                      purpose            23.163202
# 25    3.172050e-14                      purpose            15.202433
# 26    6.773720e-12                      purpose            16.443284
# 27    1.653427e-17                      purpose            20.474549
# 28    2.676211e-05          initial_list_status             4.226837
# 29    1.812804e-08                         term             6.064951
# 30    1.301621e-04                   emp_length             7.648900
# 31    2.247723e-11                   emp_length             9.728584
# 32    1.923635e-05                   emp_length             7.049576
# 33    3.054330e-03                   emp_length             4.748798
# 34    1.034983e-11                   emp_length             9.663994
# 35   7.307195e-189           mths_since_issue_d            84.197083
# 36   1.158310e-158           mths_since_issue_d            68.671600
# 37   1.874188e-131           mths_since_issue_d            60.829028
# 38    4.827482e-94           mths_since_issue_d            45.272290
# 39    8.032616e-44           mths_since_issue_d            32.773185
# 40    5.217626e-10           mths_since_issue_d            13.775148
# 41    3.499544e-02           mths_since_issue_d            -4.674590
# 42    3.709293e-30                     int_rate            66.881253
# 43    7.714578e-34                     int_rate            41.669735
# 44    1.984920e-15                     int_rate            22.454701
# 45    3.683881e-04                     int_rate             7.950618
# 46    2.316610e-02  mths_since_earliest_cr_line             4.352163
# 47    5.685032e-02  mths_since_earliest_cr_line             2.943733
# 48    2.091505e-03  mths_since_earliest_cr_line             6.216878
# 49    1.497001e-07  mths_since_earliest_cr_line             9.471809
# 50    6.940027e-07  mths_since_earliest_cr_line            10.134031
# 51    8.171735e-18               inq_last_6mths            53.546431
# 52    1.182933e-11               inq_last_6mths            42.203025
# 53    3.563451e-05               inq_last_6mths            25.956054
# 54    2.326845e-02               acc_now_delinq            18.153542
# 55    9.947818e-02                   annual_inc            -5.315306
# 56    8.904890e-01                   annual_inc            -0.426695
# 57    2.606733e-02                   annual_inc             6.886209
# 58    1.207766e-04                   annual_inc            12.054099
# 59    2.552314e-08                   annual_inc            17.867862
# 60    5.402130e-13                   annual_inc            23.612709
# 61    7.968175e-18                   annual_inc            29.323581
# 62    2.166493e-18                   annual_inc            30.900399
# 63    4.984335e-26                   annual_inc            36.962987
# 64    7.341082e-29                   annual_inc            44.492681
# 65    1.348163e-26                   annual_inc            38.960821
# 66    2.330160e-03                          dti            19.472109
# 67    8.811998e-08                          dti            28.644416
# 68    6.677722e-11                          dti            30.010455
# 69    4.306794e-08                          dti            25.030410
# 70    1.825593e-05                          dti            18.910181
# 71    1.207483e-02                          dti            11.095976
# 72    2.711004e-02                          dti            10.235084
# 73    1.288914e-01                          dti             7.517242
# 74    3.354135e-01                          dti             4.210406
# 75    3.993944e-04       mths_since_last_delinq            12.917262
# 76    6.766861e-05       mths_since_last_delinq            14.824816
# 77    1.034442e-06       mths_since_last_delinq            18.430709
# 78    1.379534e-04       mths_since_last_delinq            14.786663
# 79    2.755594e-06       mths_since_last_record             7.920808
# 80    2.358424e-02       mths_since_last_record            16.408928
# 81    9.164776e-02       mths_since_last_record            10.464310
# 82    1.251221e-18       mths_since_last_record            22.104057
# 83    4.455653e-01       mths_since_last_record            -3.845277
# 84             NaN                        grade             0.000000
# 85             NaN               home_ownership             0.000000
# 86             NaN                   addr_state             0.000000
# 87             NaN          verification_status             0.000000
# 88             NaN                      purpose             0.000000
# 89             NaN          initial_list_status             0.000000
# 90             NaN                         term             0.000000
# 91             NaN                   emp_length             0.000000
# 92             NaN           mths_since_issue_d             0.000000
# 93             NaN                     int_rate             0.000000
# 94             NaN  mths_since_earliest_cr_line             0.000000
# 95             NaN               inq_last_6mths             0.000000
# 96             NaN               acc_now_delinq             0.000000
# 97             NaN                   annual_inc             0.000000
# 98             NaN                          dti             0.000000
# 99             NaN       mths_since_last_delinq             0.000000
# 100            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference
# 0                  315.0    0.350468
# 1                   89.0   -0.099526
# 2                   70.0   -0.391665
# 3                   55.0   -0.236655
# 4                   41.0    0.494087
# 5                   26.0   -0.390835
# 6                   12.0    0.263907
# 7                    7.0   -0.225848
# 8                    8.0   -0.189905
# 9                    3.0    0.216990
# 10                   4.0   -0.455972
# 11                   5.0    0.387122
# 12                   5.0    0.069395
# 13                   6.0   -0.089840
# 14                  11.0    0.440805
# 15                   8.0    0.162153
# 16                  14.0   -0.321715
# 17                  19.0    0.461070
# 18                  17.0   -0.183674
# 19                  20.0   -0.260439
# 20                  25.0    0.254904
# 21                  40.0   -0.417198
# 22                   7.0    0.489977
# 23                  -1.0   -0.185640
# 24                  23.0   -0.163202
# 25                  15.0   -0.202433
# 26                  16.0   -0.443284
# 27                  20.0   -0.474549
# 28                   4.0   -0.226837
# 29                   6.0   -0.064951
# 30                   8.0    0.351100
# 31                  10.0    0.271416
# 32                   7.0   -0.049576
# 33                   5.0    0.251202
# 34                  10.0    0.336006
# 35                  84.0   -0.197083
# 36                  69.0    0.328400
# 37                  61.0    0.170972
# 38                  45.0   -0.272290
# 39                  33.0    0.226815
# 40                  14.0    0.224852
# 41                  -5.0   -0.325410
# 42                  67.0    0.118747
# 43                  42.0    0.330265
# 44                  22.0   -0.454701
# 45                   8.0    0.049382
# 46                   4.0   -0.352163
# 47                   3.0    0.056267
# 48                   6.0   -0.216878
# 49                   9.0   -0.471809
# 50                  10.0   -0.134031
# 51                  54.0    0.453569
# 52                  42.0   -0.203025
# 53                  26.0    0.043946
# 54                  18.0   -0.153542
# 55                  -5.0    0.315306
# 56                  -0.0    0.426695
# 57                   7.0    0.113791
# 58                  12.0   -0.054099
# 59                  18.0    0.132138
# 60                  24.0    0.387291
# 61                  29.0   -0.323581
# 62                  31.0    0.099601
# 63                  37.0    0.037013
# 64                  44.0   -0.492681
# 65                  39.0    0.039179
# 66                  19.0   -0.472109
# 67                  29.0    0.355584
# 68                  30.0   -0.010455
# 69                  25.0   -0.030410
# 70                  19.0    0.089819
# 71                  11.0   -0.095976
# 72                  10.0   -0.235084
# 73                   8.0    0.482758
# 74                   4.0   -0.210406
# 75                  13.0    0.082738
# 76                  15.0    0.175184
# 77                  18.0   -0.430709
# 78                  15.0    0.213337
# 79                   8.0    0.079192
# 80                  16.0   -0.408928
# 81                  10.0   -0.464310
# 82                  22.0   -0.104057
# 83                  -4.0   -0.154723
# 84                   0.0    0.000000
# 85                   0.0    0.000000
# 86                   0.0    0.000000
# 87                   0.0    0.000000
# 88                   0.0    0.000000
# 89                   0.0    0.000000
# 90                   0.0    0.000000
# 91                   0.0    0.000000
# 92                   0.0    0.000000
# 93                   0.0    0.000000
# 94                   0.0    0.000000
# 95                   0.0    0.000000
# 96                   0.0    0.000000
# 97                   0.0    0.000000
# 98                   0.0    0.000000
# 99                   0.0    0.000000
# 100                  0.0    0.000000

# %%
df_scorecard['Score - Final'] = df_scorecard['Score - Preliminary']
df_scorecard['Score - Final'][77] = 16
df_scorecard
# Out:
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_38239/1528914224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Final'][77] = 16
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           314.649532
# 1     2.054571e-37                        grade            89.099526
# 2     2.731773e-51                        grade            70.391665
# 3     2.225365e-37                        grade            55.236655
# 4     4.191192e-23                        grade            40.505913
# 5     3.044944e-13                        grade            26.390835
# 6     1.812154e-03                        grade            11.736093
# 7     3.282189e-06               home_ownership             7.225848
# 8     4.428816e-17               home_ownership             8.189905
# 9     2.594831e-01                   addr_state             2.783010
# 10    1.698910e-02                   addr_state             4.455972
# 11    9.726920e-03                   addr_state             4.612878
# 12    2.537804e-03                   addr_state             4.930605
# 13    1.514118e-03                   addr_state             6.089840
# 14    1.151591e-09                   addr_state            10.559195
# 15    6.562288e-04                   addr_state             7.837847
# 16    3.201430e-12                   addr_state            14.321715
# 17    4.240665e-07                   addr_state            18.538930
# 18    9.250644e-18                   addr_state            17.183674
# 19    2.218063e-19                   addr_state            20.260439
# 20    2.185174e-25                   addr_state            24.745096
# 21    6.882691e-23                   addr_state            40.417198
# 22    7.097765e-09          verification_status             6.510023
# 23    4.316255e-01          verification_status            -0.814360
# 24    2.051002e-26                      purpose            23.163202
# 25    3.172050e-14                      purpose            15.202433
# 26    6.773720e-12                      purpose            16.443284
# 27    1.653427e-17                      purpose            20.474549
# 28    2.676211e-05          initial_list_status             4.226837
# 29    1.812804e-08                         term             6.064951
# 30    1.301621e-04                   emp_length             7.648900
# 31    2.247723e-11                   emp_length             9.728584
# 32    1.923635e-05                   emp_length             7.049576
# 33    3.054330e-03                   emp_length             4.748798
# 34    1.034983e-11                   emp_length             9.663994
# 35   7.307195e-189           mths_since_issue_d            84.197083
# 36   1.158310e-158           mths_since_issue_d            68.671600
# 37   1.874188e-131           mths_since_issue_d            60.829028
# 38    4.827482e-94           mths_since_issue_d            45.272290
# 39    8.032616e-44           mths_since_issue_d            32.773185
# 40    5.217626e-10           mths_since_issue_d            13.775148
# 41    3.499544e-02           mths_since_issue_d            -4.674590
# 42    3.709293e-30                     int_rate            66.881253
# 43    7.714578e-34                     int_rate            41.669735
# 44    1.984920e-15                     int_rate            22.454701
# 45    3.683881e-04                     int_rate             7.950618
# 46    2.316610e-02  mths_since_earliest_cr_line             4.352163
# 47    5.685032e-02  mths_since_earliest_cr_line             2.943733
# 48    2.091505e-03  mths_since_earliest_cr_line             6.216878
# 49    1.497001e-07  mths_since_earliest_cr_line             9.471809
# 50    6.940027e-07  mths_since_earliest_cr_line            10.134031
# 51    8.171735e-18               inq_last_6mths            53.546431
# 52    1.182933e-11               inq_last_6mths            42.203025
# 53    3.563451e-05               inq_last_6mths            25.956054
# 54    2.326845e-02               acc_now_delinq            18.153542
# 55    9.947818e-02                   annual_inc            -5.315306
# 56    8.904890e-01                   annual_inc            -0.426695
# 57    2.606733e-02                   annual_inc             6.886209
# 58    1.207766e-04                   annual_inc            12.054099
# 59    2.552314e-08                   annual_inc            17.867862
# 60    5.402130e-13                   annual_inc            23.612709
# 61    7.968175e-18                   annual_inc            29.323581
# 62    2.166493e-18                   annual_inc            30.900399
# 63    4.984335e-26                   annual_inc            36.962987
# 64    7.341082e-29                   annual_inc            44.492681
# 65    1.348163e-26                   annual_inc            38.960821
# 66    2.330160e-03                          dti            19.472109
# 67    8.811998e-08                          dti            28.644416
# 68    6.677722e-11                          dti            30.010455
# 69    4.306794e-08                          dti            25.030410
# 70    1.825593e-05                          dti            18.910181
# 71    1.207483e-02                          dti            11.095976
# 72    2.711004e-02                          dti            10.235084
# 73    1.288914e-01                          dti             7.517242
# 74    3.354135e-01                          dti             4.210406
# 75    3.993944e-04       mths_since_last_delinq            12.917262
# 76    6.766861e-05       mths_since_last_delinq            14.824816
# 77    1.034442e-06       mths_since_last_delinq            18.430709
# 78    1.379534e-04       mths_since_last_delinq            14.786663
# 79    2.755594e-06       mths_since_last_record             7.920808
# 80    2.358424e-02       mths_since_last_record            16.408928
# 81    9.164776e-02       mths_since_last_record            10.464310
# 82    1.251221e-18       mths_since_last_record            22.104057
# 83    4.455653e-01       mths_since_last_record            -3.845277
# 84             NaN                        grade             0.000000
# 85             NaN               home_ownership             0.000000
# 86             NaN                   addr_state             0.000000
# 87             NaN          verification_status             0.000000
# 88             NaN                      purpose             0.000000
# 89             NaN          initial_list_status             0.000000
# 90             NaN                         term             0.000000
# 91             NaN                   emp_length             0.000000
# 92             NaN           mths_since_issue_d             0.000000
# 93             NaN                     int_rate             0.000000
# 94             NaN  mths_since_earliest_cr_line             0.000000
# 95             NaN               inq_last_6mths             0.000000
# 96             NaN               acc_now_delinq             0.000000
# 97             NaN                   annual_inc             0.000000
# 98             NaN                          dti             0.000000
# 99             NaN       mths_since_last_delinq             0.000000
# 100            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  315.0    0.350468          315.0
# 1                   89.0   -0.099526           89.0
# 2                   70.0   -0.391665           70.0
# 3                   55.0   -0.236655           55.0
# 4                   41.0    0.494087           41.0
# 5                   26.0   -0.390835           26.0
# 6                   12.0    0.263907           12.0
# 7                    7.0   -0.225848            7.0
# 8                    8.0   -0.189905            8.0
# 9                    3.0    0.216990            3.0
# 10                   4.0   -0.455972            4.0
# 11                   5.0    0.387122            5.0
# 12                   5.0    0.069395            5.0
# 13                   6.0   -0.089840            6.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].min().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Sums all minimum values.
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].max().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Sums all maximum values.
max_sum_score_prel
# Out:
# 847.0

# %% [markdown]
# ### Caclulating Credit Score

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86
# 362514                             0
# 288564                             0
# 213591                             0
# 263083                             0
# 165001                             0

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           314.649532
# 1     2.054571e-37                        grade            89.099526
# 2     2.731773e-51                        grade            70.391665
# 3     2.225365e-37                        grade            55.236655
# 4     4.191192e-23                        grade            40.505913
# 5     3.044944e-13                        grade            26.390835
# 6     1.812154e-03                        grade            11.736093
# 7     3.282189e-06               home_ownership             7.225848
# 8     4.428816e-17               home_ownership             8.189905
# 9     2.594831e-01                   addr_state             2.783010
# 10    1.698910e-02                   addr_state             4.455972
# 11    9.726920e-03                   addr_state             4.612878
# 12    2.537804e-03                   addr_state             4.930605
# 13    1.514118e-03                   addr_state             6.089840
# 14    1.151591e-09                   addr_state            10.559195
# 15    6.562288e-04                   addr_state             7.837847
# 16    3.201430e-12                   addr_state            14.321715
# 17    4.240665e-07                   addr_state            18.538930
# 18    9.250644e-18                   addr_state            17.183674
# 19    2.218063e-19                   addr_state            20.260439
# 20    2.185174e-25                   addr_state            24.745096
# 21    6.882691e-23                   addr_state            40.417198
# 22    7.097765e-09          verification_status             6.510023
# 23    4.316255e-01          verification_status            -0.814360
# 24    2.051002e-26                      purpose            23.163202
# 25    3.172050e-14                      purpose            15.202433
# 26    6.773720e-12                      purpose            16.443284
# 27    1.653427e-17                      purpose            20.474549
# 28    2.676211e-05          initial_list_status             4.226837
# 29    1.812804e-08                         term             6.064951
# 30    1.301621e-04                   emp_length             7.648900
# 31    2.247723e-11                   emp_length             9.728584
# 32    1.923635e-05                   emp_length             7.049576
# 33    3.054330e-03                   emp_length             4.748798
# 34    1.034983e-11                   emp_length             9.663994
# 35   7.307195e-189           mths_since_issue_d            84.197083
# 36   1.158310e-158           mths_since_issue_d            68.671600
# 37   1.874188e-131           mths_since_issue_d            60.829028
# 38    4.827482e-94           mths_since_issue_d            45.272290
# 39    8.032616e-44           mths_since_issue_d            32.773185
# 40    5.217626e-10           mths_since_issue_d            13.775148
# 41    3.499544e-02           mths_since_issue_d            -4.674590
# 42    3.709293e-30                     int_rate            66.881253
# 43    7.714578e-34                     int_rate            41.669735
# 44    1.984920e-15                     int_rate            22.454701
# 45    3.683881e-04                     int_rate             7.950618
# 46    2.316610e-02  mths_since_earliest_cr_line             4.352163
# 47    5.685032e-02  mths_since_earliest_cr_line             2.943733
# 48    2.091505e-03  mths_since_earliest_cr_line             6.216878
# 49    1.497001e-07  mths_since_earliest_cr_line             9.471809
# 50    6.940027e-07  mths_since_earliest_cr_line            10.134031
# 51    8.171735e-18               inq_last_6mths            53.546431
# 52    1.182933e-11               inq_last_6mths            42.203025
# 53    3.563451e-05               inq_last_6mths            25.956054
# 54    2.326845e-02               acc_now_delinq            18.153542
# 55    9.947818e-02                   annual_inc            -5.315306
# 56    8.904890e-01                   annual_inc            -0.426695
# 57    2.606733e-02                   annual_inc             6.886209
# 58    1.207766e-04                   annual_inc            12.054099
# 59    2.552314e-08                   annual_inc            17.867862
# 60    5.402130e-13                   annual_inc            23.612709
# 61    7.968175e-18                   annual_inc            29.323581
# 62    2.166493e-18                   annual_inc            30.900399
# 63    4.984335e-26                   annual_inc            36.962987
# 64    7.341082e-29                   annual_inc            44.492681
# 65    1.348163e-26                   annual_inc            38.960821
# 66    2.330160e-03                          dti            19.472109
# 67    8.811998e-08                          dti            28.644416
# 68    6.677722e-11                          dti            30.010455
# 69    4.306794e-08                          dti            25.030410
# 70    1.825593e-05                          dti            18.910181
# 71    1.207483e-02                          dti            11.095976
# 72    2.711004e-02                          dti            10.235084
# 73    1.288914e-01                          dti             7.517242
# 74    3.354135e-01                          dti             4.210406
# 75    3.993944e-04       mths_since_last_delinq            12.917262
# 76    6.766861e-05       mths_since_last_delinq            14.824816
# 77    1.034442e-06       mths_since_last_delinq            18.430709
# 78    1.379534e-04       mths_since_last_delinq            14.786663
# 79    2.755594e-06       mths_since_last_record             7.920808
# 80    2.358424e-02       mths_since_last_record            16.408928
# 81    9.164776e-02       mths_since_last_record            10.464310
# 82    1.251221e-18       mths_since_last_record            22.104057
# 83    4.455653e-01       mths_since_last_record            -3.845277
# 84             NaN                        grade             0.000000
# 85             NaN               home_ownership             0.000000
# 86             NaN                   addr_state             0.000000
# 87             NaN          verification_status             0.000000
# 88             NaN                      purpose             0.000000
# 89             NaN          initial_list_status             0.000000
# 90             NaN                         term             0.000000
# 91             NaN                   emp_length             0.000000
# 92             NaN           mths_since_issue_d             0.000000
# 93             NaN                     int_rate             0.000000
# 94             NaN  mths_since_earliest_cr_line             0.000000
# 95             NaN               inq_last_6mths             0.000000
# 96             NaN               acc_now_delinq             0.000000
# 97             NaN                   annual_inc             0.000000
# 98             NaN                          dti             0.000000
# 99             NaN       mths_since_last_delinq             0.000000
# 100            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  315.0    0.350468          315.0
# 1                   89.0   -0.099526           89.0
# 2                   70.0   -0.391665           70.0
# 3                   55.0   -0.236655           55.0
# 4                   41.0    0.494087           41.0
# 5                   26.0   -0.390835           26.0
# 6                   12.0    0.263907           12.0
# 7                    7.0   -0.225848            7.0
# 8                    8.0   -0.189905            8.0
# 9                    3.0    0.216990            3.0
# 93                   0.0    0.000000            0.0
# 94                   0.0    0.000000            0.0
# 95                   0.0    0.000000            0.0
# 96                   0.0    0.000000            0.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat

# %%
inputs_test_with_ref_cat_w_intercept.insert(0, 'Intercept', 1)
# We insert a column in the dataframe, with an index of 0, that is, in the beginning of the dataframe.
# The name of that column is 'Intercept', and its values are 1s.

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         grade:G  home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514        0                                   0                   0
# 288564        0                                   0                   0
# 213591        0                                   0                   0
# 263083        0                                   0                   0
# 165001        0                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86
# 362514                             0
# 288564                             0
# 213591                             0
# 263083                             0
# 165001                             0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat_w_intercept[df_scorecard['Feature name'].values]
# Here, from the 'inputs_test_with_ref_cat_w_intercept' dataframe, we keep only the columns with column names,
# exactly equal to the row values of the 'Feature name' column from the 'df_scorecard' dataframe.

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 362514              0                             0              1
# 288564              0                             0              0
# 213591              0                             0              0
# 263083              0                             0              0
# 165001              0                             0              0
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514                       0                          0
# 288564                       0                          0
# 213591                       1                          0
# 263083                       0                          1
# 165001                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 362514                                    0                    0
# 288564                                    0                    1
# 213591                                    0                    0
# 263083                                    1                    0
# 165001                                    0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 362514                                    1                      0        0
# 288564                                    0                      1        0
# 213591                                    0                      0        1
# 263083                                    0                      1        0
# 165001                                    0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 362514             0               0               0               0
# 288564             0               0               0               0
# 213591             1               0               0               0
# 263083             0               1               0               0
# 165001             0               0               0               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514              0                       0                         0
# 288564              1                       0                         1
# 213591              0                       0                         0
# 263083              0                       1                         0
# 165001              1                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 362514                         0                0                      0
# 288564                         0                0                      0
# 213591                         1                0                      0
# 263083                         0                0                      0
# 165001                         0                1                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      1                      0
# 288564                      0                      0
# 213591                      1                      0
# 263083                      1                      0
# 165001                      0                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         acc_now_delinq:>=1  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 362514              0              0              0            0
# 288564              0              0              0            1
# 213591              0              0              0            0
# 263083              1              0              0            0
# 165001              0              0              0            0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 362514                               1                            0
# 288564                               0                            0
# 213591                               0                            0
# 263083                               1                            0
# 165001                               0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 362514                               1                            0
# 288564                               1                            0
# 213591                               1                            0
# 263083                               1                            0
# 165001                               1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  grade:G  \
# 362514                             0        0
# 288564                             0        0
# 213591                             0        0
# 263083                             0        0
# 165001                             0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                                   0                                0
# 288564                                   0                                0
# 213591                                   0                                0
# 263083                                   0                                0
# 165001                                   0                                0
#
#         verification_status:Verified  \
# 362514                             1
# 288564                             1
# 213591                             1
# 263083                             0
# 165001                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  initial_list_status:f  \
# 362514                                             0                      1
# 288564                                             0                      0
# 213591                                             0                      1
# 263083                                             0                      0
# 165001                                             0                      1
#
#         term:60  emp_length:0  mths_since_issue_d:>84  int_rate:>20.281  \
# 362514        1             1                       0                 0
# 288564        1             0                       0                 1
# 213591        0             0                       0                 0
# 263083        1             0                       0                 0
# 165001        0             0                       0                 0
#
#         mths_since_earliest_cr_line:<140  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                                 0                  0                 1
# 288564                                 0                  0                 1
# 213591                                 0                  0                 1
# 263083                                 1                  0                 1
# 165001                                 0                  0                 1
#
#         annual_inc:<20K  dti:>35  mths_since_last_delinq:0-3  \
# 362514                0        0                           0
# 288564                0        0                           1
# 213591                0        0                           0
# 263083                0        0                           0
# 165001                0        0                           0
#
#         mths_since_last_record:0-2
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0

# %%
scorecard_scores = df_scorecard['Score - Final']

# %%
inputs_test_with_ref_cat_w_intercept.shape
# Out:
# (93257, 101)

# %%
scorecard_scores.shape
# Out:
# (101,)

# %%
scorecard_scores = scorecard_scores.values.reshape(101, 1)

# %%
scorecard_scores.shape
# Out:
# (101, 1)

# %%
y_scores = inputs_test_with_ref_cat_w_intercept.dot(scorecard_scores)
# Here we multiply the values of each row of the dataframe by the values of each column of the variable,
# which is an argument of the 'dot' method, and sum them. It's essentially the sum of the products.

# %%
y_scores.head()
# Out:
#             0
# 362514  607.0
# 288564  544.0
# 213591  569.0
# 263083  627.0
# 165001  677.0

# %%
y_scores.tail()
# Out:
#             0
# 115     568.0
# 296284  674.0
# 61777   692.0
# 91763   659.0
# 167512  646.0

# %% [markdown]
# ### From Credit Score to PD

# %%
sum_coef_from_score = ((y_scores - min_score) / (max_score - min_score)) * (max_sum_coef - min_sum_coef) + min_sum_coef
# We divide the difference between the scores and the minimum score by
# the difference between the maximum score and the minimum score.
# Then, we multiply that by the difference between the maximum sum of coefficients and the minimum sum of coefficients.
# Then, we add the minimum sum of coefficients.

# %%
y_hat_proba_from_score = np.exp(sum_coef_from_score) / (np.exp(sum_coef_from_score) + 1)
# Here we divide an exponent raised to sum of coefficients from score by
# an exponent raised to sum of coefficients from score plus one.
y_hat_proba_from_score.head()
# Out:
#                0
# 362514  0.924494
# 288564  0.843955
# 213591  0.882071
# 263083  0.940723
# 165001  0.968105

# %%
y_hat_test_proba[0: 5]
# Out:
# array([0.92448608, 0.84304655, 0.88550117, 0.94070735, 0.96868925])

# %%
df_actual_predicted_probs['y_hat_test_proba'].head()
# Out:
# 0    0.380877
# 1    0.398076
# 2    0.431713
# 3    0.435310
# 4    0.455460
# Name: y_hat_test_proba, dtype: float64

# %% [markdown]
# ### Setting Cut-offs

# %%
# We need the confusion matrix again.
#np.where(np.squeeze(np.array(loan_data_targets_test)) == np.where(y_hat_test_proba >= tr, 1, 0), 1, 0).sum() / loan_data_targets_test.shape[0]
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)
#df_actual_predicted_probs['loan_data_targets_test'] == np.where(df_actual_predicted_probs['y_hat_test_proba'] >= tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0           7379   2811
# 1          35830  47237

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.079125  0.030143
# 1          0.384207  0.506525

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.5856504069399616

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99990186, 0.99990186,
#         1.        ]),
#  array([0.00000000e+00, 1.20384750e-05, 1.20384750e-04, ...,
#         9.99975923e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([1.99271448, 0.99271448, 0.99072892, ..., 0.43531043, 0.39807591,
#         0.38087713]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
thresholds
# Out:
# array([1.99271448, 0.99271448, 0.99072892, ..., 0.43531043, 0.39807591,
#        0.38087713])

# %%
thresholds.shape
# Out:
# (17374,)

# %%
df_cutoffs = pd.concat([pd.DataFrame(thresholds), pd.DataFrame(fpr), pd.DataFrame(tpr)], axis = 1)
# We concatenate 3 dataframes along the columns.

# %%
df_cutoffs.columns = ['thresholds', 'fpr', 'tpr']
# We name the columns of the dataframe 'thresholds', 'fpr', and 'tpr'.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr
# 0    1.992714  0.000000  0.000000
# 1    0.992714  0.000000  0.000012
# 2    0.990729  0.000000  0.000120
# 3    0.990725  0.000098  0.000120
# 4    0.989778  0.000098  0.000457

# %%
df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)
# Let the first threshold (the value of the thresholds column with index 0) be equal to a number, very close to 1
# but smaller than 1, say 1 - 1 / 10 ^ 16.

# %%
df_cutoffs['Score'] = ((np.log(df_cutoffs['thresholds'] / (1 - df_cutoffs['thresholds'])) - min_sum_coef) * ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
# The score corresponsing to each threshold equals:
# The the difference between the natural logarithm of the ratio of the threshold and 1 minus the threshold and
# the minimum sum of coefficients
# multiplied by
# the sum of the minimum score and the ratio of the difference between the maximum score and minimum score and 
# the difference between the maximum sum of coefficients and the minimum sum of coefficients.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr   Score
# 0    1.000000  0.000000  0.000000  3246.0
# 1    0.992714  0.000000  0.000012   793.0
# 2    0.990729  0.000000  0.000120   774.0
# 3    0.990725  0.000098  0.000120   774.0
# 4    0.989778  0.000098  0.000457   766.0

# %%
df_cutoffs['Score'][0] = max_score

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score
# 0    1.000000  0.000000  0.000000  850.0
# 1    0.992714  0.000000  0.000012  793.0
# 2    0.990729  0.000000  0.000120  774.0
# 3    0.990725  0.000098  0.000120  774.0
# 4    0.989778  0.000098  0.000457  766.0

# %%
df_cutoffs.tail()
# Out:
#        thresholds       fpr       tpr  Score
# 17369    0.484578  0.999706  0.999952  409.0
# 17370    0.477783  0.999706  0.999976  407.0
# 17371    0.435310  0.999902  0.999976  394.0
# 17372    0.398076  0.999902  1.000000  382.0
# 17373    0.380877  1.000000  1.000000  376.0

# %%
# We define a function called 'n_approved' which assigns a value of 1 if a predicted probability
# is greater than the parameter p, which is a threshold, and a value of 0, if it is not.
# Then it sums the column.
# Thus, if given any percentage values, the function will return
# the number of rows wih estimated probabilites greater than the threshold. 
def n_approved(p):
    return np.where(df_actual_predicted_probs['y_hat_test_proba'] >= p, 1, 0).sum()

# %%
df_cutoffs['N Approved'] = df_cutoffs['thresholds'].apply(n_approved)
# Assuming that all credit applications above a given probability of being 'good' will be approved,
# when we apply the 'n_approved' function to a threshold, it will return the number of approved applications.
# Thus, here we calculate the number of approved appliations for al thresholds.
df_cutoffs['N Rejected'] = df_actual_predicted_probs['y_hat_test_proba'].shape[0] - df_cutoffs['N Approved']
# Then, we calculate the number of rejected applications for each threshold.
# It is the difference between the total number of applications and the approved applications for that threshold.
df_cutoffs['Approval Rate'] = df_cutoffs['N Approved'] / df_actual_predicted_probs['y_hat_test_proba'].shape[0]
# Approval rate equalts the ratio of the approved applications and all applications.
df_cutoffs['Rejection Rate'] = 1 - df_cutoffs['Approval Rate']
# Rejection rate equals one minus approval rate.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 0    1.000000  0.000000  0.000000  850.0           0       93257
# 1    0.992714  0.000000  0.000012  793.0           1       93256
# 2    0.990729  0.000000  0.000120  774.0          10       93247
# 3    0.990725  0.000098  0.000120  774.0          11       93246
# 4    0.989778  0.000098  0.000457  766.0          39       93218
#
#    Approval Rate  Rejection Rate
# 0       0.000000        1.000000
# 1       0.000011        0.999989
# 2       0.000107        0.999893
# 3       0.000118        0.999882
# 4       0.000418        0.999582

# %%
df_cutoffs.tail()
# Out:
#        thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 17369    0.484578  0.999706  0.999952  409.0       93250           7
# 17370    0.477783  0.999706  0.999976  407.0       93252           5
# 17371    0.435310  0.999902  0.999976  394.0       93254           3
# 17372    0.398076  0.999902  1.000000  382.0       93256           1
# 17373    0.380877  1.000000  1.000000  376.0       93257           0
#
#        Approval Rate  Rejection Rate
# 17369       0.999925        0.000075
# 17370       0.999946        0.000054
# 17371       0.999968        0.000032
# 17372       0.999989        0.000011
# 17373       1.000000        0.000000

# %%
df_cutoffs.iloc[5000: 6200, ]
# Here we display the dataframe with cutoffs form line with index 5000 to line with index 6200.
# Out:
#       thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 1943       0.292664        0.707336
# 1944       0.292707        0.707293
# 1945       0.292718        0.707282
# 1946       0.293329        0.706671
# 1947       0.293340        0.706660
# 1948       0.293544        0.706456
# 1949       0.293554        0.706446
# 1950       0.293704        0.706296
# 1951       0.293715        0.706285
# 1952       0.293801        0.706199
# 1953       0.293812        0.706188
# 1954       0.293898        0.706102
# 1955       0.293908        0.706092
# 1956       0.293973        0.706027
# 1957       0.293983        0.706017
# 1958       0.294112        0.705888
# 1959       0.294123        0.705877
# 1960       0.294326        0.705674
# 1961       0.294337        0.705663
# 1962       0.294401        0.705599
# 1963       0.294412        0.705588
# 1964       0.294509        0.705491
# 1965       0.294519        0.705481
# 1966       0.294552        0.705448
# 1967       0.294562        0.705438
# 1968       0.294648        0.705352
# 1969       0.294659        0.705341
# 1970       0.295206        0.704794
# 1971       0.295216        0.704784
# 1972       0.295495        0.704505
# 1973       0.295506        0.704494
# 1974       0.295538        0.704462
# 1975       0.295549        0.704451
# 1976       0.295678        0.704322
# 1977       0.295688        0.704312
# 1978       0.295871        0.704129
# 1979       0.295881        0.704119
# 1980       0.296064        0.703936
# 1981       0.296074        0.703926
# 1982       0.296396        0.703604
# 1983       0.296407        0.703593
# 1984       0.296428        0.703572
# 1985       0.296439        0.703561
# 1986       0.296803        0.703197
# 1987       0.296814        0.703186
# 1988       0.296986        0.703014
# 1989       0.296996        0.703004
# 1990       0.297029        0.702971
# 1991       0.297039        0.702961
# 1992       0.297147        0.702853
# 1993       0.297157        0.702843
# 1994       0.297179        0.702821
# 1995       0.297189        0.702811
# 1996       0.297350        0.702650
# 1997       0.297361        0.702639
# 1998       0.297372        0.702628
# 1999       0.297383        0.702617

# %%
inputs_train_with_ref_cat.to_csv('inputs_train_with_ref_cat.csv')

# %%
df_scorecard.to_csv('df_scorecard.csv')

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286591
# 1        1                                       grade:A      1.155571
# 2        2                                       grade:B      0.912941
# 3        3                                       grade:C      0.716389
# 4        4                                       grade:D      0.525339
# 5        5                                       grade:E      0.342274
# 6        6                                       grade:F      0.152211
# 7        7                            home_ownership:OWN      0.093715
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036094
# 10      10                                 addr_state:NY      0.057791
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059826
# 12      12                                 addr_state:CA      0.063947
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078982
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136947
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101652
# 16      16                           addr_state:GA_WA_OR      0.185745
# 17      17                              addr_state:WI_MT      0.240440
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262767
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524189
# 22      22              verification_status:Not Verified      0.084431
# 23      23           verification_status:Source Verified     -0.010562
# 24      24                           purpose:credit_card      0.300414
# 25      25                    purpose:debt_consolidation      0.197167
# 26      26                    purpose:oth__med__vacation      0.213260
# 27      27           purpose:major_purch__car__home_impr      0.265543
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078659
# 30      30                                  emp_length:1      0.099202
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125337
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425050
# 40      40                      mths_since_issue_d:53-64      0.178656
# 41      41                      mths_since_issue_d:65-84     -0.060627
# 42      42                               int_rate:<9.548      0.867413
# 43      43                         int_rate:9.548-12.025      0.540433
# 44      44                         int_rate:12.025-15.74      0.291225
# 45      45                         int_rate:15.74-20.281      0.103115
# 46      46           mths_since_earliest_cr_line:141-164      0.056445
# 47      47           mths_since_earliest_cr_line:165-247      0.038179
# 48      48           mths_since_earliest_cr_line:248-270      0.080629
# 49      49           mths_since_earliest_cr_line:271-352      0.122844
# 50      50              mths_since_earliest_cr_line:>352      0.131433
# 51      51                              inq_last_6mths:0      0.694467
# 52      52                            inq_last_6mths:1-2      0.547350
# 53      53                            inq_last_6mths:3-6      0.336636
# 54      54                            acc_now_delinq:>=1      0.235441
# 55      55                            annual_inc:20K-30K     -0.068937
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306244
# 61      61                            annual_inc:80K-90K      0.380310
# 62      62                           annual_inc:90K-100K      0.400761
# 63      63                          annual_inc:100K-120K      0.479389
# 64      64                          annual_inc:120K-140K      0.577045
# 65      65                              annual_inc:>140K      0.505300
# 66      66                                     dti:<=1.4      0.252542
# 67      67                                   dti:1.4-3.5      0.371502
# 68      68                                   dti:3.5-7.7      0.389219
# 69      69                                  dti:7.7-10.5      0.324630
# 70      70                                 dti:10.5-16.1      0.245254
# 71      71                                 dti:16.1-20.3      0.143909
# 72      72                                 dti:20.3-21.7      0.132743
# 73      73                                 dti:21.7-22.4      0.097494
# 74      74                                   dti:22.4-35      0.054607
# 75      75                mths_since_last_delinq:Missing      0.167530
# 76      76                   mths_since_last_delinq:4-30      0.192270
# 77      77                  mths_since_last_delinq:31-56      0.239036
# 78      78                   mths_since_last_delinq:>=57      0.191775
# 79      79                mths_since_last_record:Missing      0.102728
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135716
# 82      82                  mths_since_last_record:32-80      0.286677
# 83      83                  mths_since_last_record:81-86     -0.049871
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           314.649532
# 1     2.054571e-37                        grade            89.099526
# 2     2.731773e-51                        grade            70.391665
# 3     2.225365e-37                        grade            55.236655
# 4     4.191192e-23                        grade            40.505913
# 5     3.044944e-13                        grade            26.390835
# 6     1.812154e-03                        grade            11.736093
# 7     3.282189e-06               home_ownership             7.225848
# 8     4.428816e-17               home_ownership             8.189905
# 9     2.594831e-01                   addr_state             2.783010
# 10    1.698910e-02                   addr_state             4.455972
# 11    9.726920e-03                   addr_state             4.612878
# 12    2.537804e-03                   addr_state             4.930605
# 13    1.514118e-03                   addr_state             6.089840
# 14    1.151591e-09                   addr_state            10.559195
# 15    6.562288e-04                   addr_state             7.837847
# 16    3.201430e-12                   addr_state            14.321715
# 17    4.240665e-07                   addr_state            18.538930
# 18    9.250644e-18                   addr_state            17.183674
# 19    2.218063e-19                   addr_state            20.260439
# 20    2.185174e-25                   addr_state            24.745096
# 21    6.882691e-23                   addr_state            40.417198
# 22    7.097765e-09          verification_status             6.510023
# 23    4.316255e-01          verification_status            -0.814360
# 24    2.051002e-26                      purpose            23.163202
# 25    3.172050e-14                      purpose            15.202433
# 26    6.773720e-12                      purpose            16.443284
# 27    1.653427e-17                      purpose            20.474549
# 28    2.676211e-05          initial_list_status             4.226837
# 29    1.812804e-08                         term             6.064951
# 30    1.301621e-04                   emp_length             7.648900
# 31    2.247723e-11                   emp_length             9.728584
# 32    1.923635e-05                   emp_length             7.049576
# 33    3.054330e-03                   emp_length             4.748798
# 34    1.034983e-11                   emp_length             9.663994
# 35   7.307195e-189           mths_since_issue_d            84.197083
# 36   1.158310e-158           mths_since_issue_d            68.671600
# 37   1.874188e-131           mths_since_issue_d            60.829028
# 38    4.827482e-94           mths_since_issue_d            45.272290
# 39    8.032616e-44           mths_since_issue_d            32.773185
# 40    5.217626e-10           mths_since_issue_d            13.775148
# 41    3.499544e-02           mths_since_issue_d            -4.674590
# 42    3.709293e-30                     int_rate            66.881253
# 43    7.714578e-34                     int_rate            41.669735
# 44    1.984920e-15                     int_rate            22.454701
# 45    3.683881e-04                     int_rate             7.950618
# 46    2.316610e-02  mths_since_earliest_cr_line             4.352163
# 47    5.685032e-02  mths_since_earliest_cr_line             2.943733
# 48    2.091505e-03  mths_since_earliest_cr_line             6.216878
# 49    1.497001e-07  mths_since_earliest_cr_line             9.471809
# 50    6.940027e-07  mths_since_earliest_cr_line            10.134031
# 51    8.171735e-18               inq_last_6mths            53.546431
# 52    1.182933e-11               inq_last_6mths            42.203025
# 53    3.563451e-05               inq_last_6mths            25.956054
# 54    2.326845e-02               acc_now_delinq            18.153542
# 55    9.947818e-02                   annual_inc            -5.315306
# 56    8.904890e-01                   annual_inc            -0.426695
# 57    2.606733e-02                   annual_inc             6.886209
# 58    1.207766e-04                   annual_inc            12.054099
# 59    2.552314e-08                   annual_inc            17.867862
# 60    5.402130e-13                   annual_inc            23.612709
# 61    7.968175e-18                   annual_inc            29.323581
# 62    2.166493e-18                   annual_inc            30.900399
# 63    4.984335e-26                   annual_inc            36.962987
# 64    7.341082e-29                   annual_inc            44.492681
# 65    1.348163e-26                   annual_inc            38.960821
# 66    2.330160e-03                          dti            19.472109
# 67    8.811998e-08                          dti            28.644416
# 68    6.677722e-11                          dti            30.010455
# 69    4.306794e-08                          dti            25.030410
# 70    1.825593e-05                          dti            18.910181
# 71    1.207483e-02                          dti            11.095976
# 72    2.711004e-02                          dti            10.235084
# 73    1.288914e-01                          dti             7.517242
# 74    3.354135e-01                          dti             4.210406
# 75    3.993944e-04       mths_since_last_delinq            12.917262
# 76    6.766861e-05       mths_since_last_delinq            14.824816
# 77    1.034442e-06       mths_since_last_delinq            18.430709
# 78    1.379534e-04       mths_since_last_delinq            14.786663
# 79    2.755594e-06       mths_since_last_record             7.920808
# 80    2.358424e-02       mths_since_last_record            16.408928
# 81    9.164776e-02       mths_since_last_record            10.464310
# 82    1.251221e-18       mths_since_last_record            22.104057
# 83    4.455653e-01       mths_since_last_record            -3.845277
# 84             NaN                        grade             0.000000
# 85             NaN               home_ownership             0.000000
# 86             NaN                   addr_state             0.000000
# 87             NaN          verification_status             0.000000
# 88             NaN                      purpose             0.000000
# 89             NaN          initial_list_status             0.000000
# 90             NaN                         term             0.000000
# 91             NaN                   emp_length             0.000000
# 92             NaN           mths_since_issue_d             0.000000
# 93             NaN                     int_rate             0.000000
# 94             NaN  mths_since_earliest_cr_line             0.000000
# 95             NaN               inq_last_6mths             0.000000
# 96             NaN               acc_now_delinq             0.000000
# 97             NaN                   annual_inc             0.000000
# 98             NaN                          dti             0.000000
# 99             NaN       mths_since_last_delinq             0.000000
# 100            NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  315.0    0.350468          315.0
# 1                   89.0   -0.099526           89.0
# 2                   70.0   -0.391665           70.0
# 3                   55.0   -0.236655           55.0
# 4                   41.0    0.494087           41.0
# 5                   26.0   -0.390835           26.0
# 6                   12.0    0.263907           12.0
# 7                    7.0   -0.225848            7.0
# 8                    8.0   -0.189905            8.0
# 9                    3.0    0.216990            3.0
# 10                   4.0   -0.455972            4.0
# 11                   5.0    0.387122            5.0
# 12                   5.0    0.069395            5.0
# 13                   6.0   -0.089840            6.0
# 14                  11.0    0.440805           11.0
# 15                   8.0    0.162153            8.0
# 16                  14.0   -0.321715           14.0
# 17                  19.0    0.461070           19.0
